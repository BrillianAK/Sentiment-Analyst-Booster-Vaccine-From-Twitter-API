# %% [markdown]
# # Sentistrength Label
#
# Sentiment Strength Detection in Bahasa Indonesia.
#
# Please cite this paper if you use this program:
#
# Wahid, D. H., & Azhari, S. N. (2016). Peringkasan Sentimen Esktraktif di Twitter Menggunakan Hybrid TF-IDF dan Cosine Similarity. IJCCS (Indonesian Journal of Computing and Cybernetics Systems), 10(2), 207-218.

# %% [markdown]
# ## Import Libary

# %%
import re
from collections import OrderedDict
import numpy as np

# %% [markdown]
# ## Code

# %%
class sentistrength:
    def __init__(self, config=dict()):
        self.negasi = [line.replace('\n','') for line in open("/content/drive/MyDrive/RISET SENTIMENT ANALYSIS/Coding/sentistrength-id/negatingword.txt").read().splitlines()]
        self.tanya = [line.replace('\n','') for line in open("/content/drive/MyDrive/RISET SENTIMENT ANALYSIS/Coding/sentistrength-id/negatingword.txt").read().splitlines()]
        #create sentiment words dictionary
        self.sentiwords_txt = [line.replace('\n','').split(":") for line in open("/content/drive/MyDrive/RISET SENTIMENT ANALYSIS/Coding/sentistrength-id/sentiwords_id.txt").read().splitlines()]
        self.sentiwords_dict = OrderedDict()
        for term in self.sentiwords_txt:
            self.sentiwords_dict[term[0]] = int(term[1])
        #create emoticon dictionary
        self.emoticon_txt = [line.replace('\n','').split(" | ") for line in open("/content/drive/MyDrive/RISET SENTIMENT ANALYSIS/Coding/sentistrength-id/emoticon_id.txt").read().splitlines()]
        self.emoticon_dict = OrderedDict()
        for term in self.emoticon_txt:
            self.emoticon_dict[term[0]] = int(term[1])
        #create idioms dictionary
        self.idioms_txt = [line.replace('\n','').split(":") for line in open("/content/drive/MyDrive/RISET SENTIMENT ANALYSIS/Coding/sentistrength-id/idioms_id.txt").read().splitlines()]
        self.idioms_dict = OrderedDict()
        for term in self.idioms_txt:
            self.idioms_dict[term[0]] = int(term[1])
        #create boosterwords dictionary
        self.boosterwords_txt = [line.replace('\n','').split(":") for line in open("/content/drive/MyDrive/RISET SENTIMENT ANALYSIS/Coding/sentistrength-id/boosterwords_id.txt").read().splitlines()]
        self.boosterwords_dict = OrderedDict()
        for term in self.boosterwords_txt:
            self.boosterwords_dict[term[0]] = int(term[1])
        self.negation_conf = config["negation"]
        self.booster_conf = config["booster"]
        self.ungkapan_conf = config["ungkapan"]
        self.consecutive_conf = config["consecutive"]
        self.repeated_conf = config["repeated"]
        self.emoticon_conf = config["emoticon"]
        self.question_conf = config["question"]
        self.exclamation_conf = config["exclamation"]
        self.punctuation_conf = config["punctuation"]
        self.mean_conf = False

    def senti(self,term):
        try:
            return self.sentiwords_dict[term]
        except:
            return 0

    def emosikon(self,term):
        try:
            return self.emoticon_dict[term]
        except:
            return 0

    def ungkapan(self,term):
        try:
            return self.idioms_dict[term]
        except:
            return 0

    def booster(self, term):
        try:
            return self.boosterwords_dict[term]
        except:
            return 0

    def cek_negationword(self, prev_term, prev_term2):
        #jika kata sebelumnya (index-1) adalah kata negasi, negasikan nilai -+nya
        if prev_term in self.negasi or prev_term2+" "+prev_term in self.negasi:
            # print prev_term
            self.score = -abs(self.score) if self.score>0 else abs(self.score)

    def cek_boosterword(self,term):
        booster_score = self.booster(term)
        if booster_score !=0 and self.score>0: self.score += booster_score
        if booster_score !=0 and self.score<0: self.score -= booster_score

    def cek_consecutive_term(self, prev_term):
        if self.prev_score>0 and self.score >=3: self.score+=1 
        if self.prev_score<0 and self.score <=-3: self.score-=1 

    def cek_ungkapan(self, bigram,trigram, i):
        bigram = ' '.join(bigram)
        trigram = ' '.join(trigram)
        ungkapan_score = self.ungkapan(bigram)
        if ungkapan_score==0:
            ungkapan_score = self.ungkapan(trigram)
        if ungkapan_score!=0:
            self.score = ungkapan_score
            self.prev_score = 0
            self.pre_max_pos[i-1] = 1
            self.pre_max_neg[i-1] = -1
            self.max_pos = self.pre_max_pos[i-2] #if len(self.pre_max_pos)>1 else 1
            self.max_neg = self.pre_max_neg[i-2] #if len(self.pre_max_neg)>1 else -1
            self.sentence_score[i-1] = re.sub(r'\[\d\]','',self.sentence_score[i-1])

    def cek_repeated_punctuation(self, next_term):
        if re.search(r'!{2,}',next_term) and self.score >=3: self.score+=1
        if re.search(r'!{2,}',next_term) and self.score <=-3: self.score-=1

    def remove_extra_repeated_char(self, term):
        return re.sub(r'([A-Za-z])\1{2,}',r'\1',term)
    def plural_to_singular(self, term):
        return re.sub(r'([A-Za-z]+)\-\1', r'\1',term)
    def classify(self):
        result = "neutral"
        try:
            if self.mean_conf:
                mean_p = np.mean(self.mean_pos)
                mean_n = np.mean(self.mean_neg)
                # print mean_p, mean_n
                if mean_p > mean_n:
                    result = "positive"
                elif mean_p < mean_n and not self.is_tanya:
                    result = "negative"
                elif mean_p < mean_n and self.is_tanya:
                    result = "neutral"
            else:
                if abs(self.sentences_max_pos) > abs(self.sentences_max_neg):
                    result = "positive"
                elif abs(self.sentences_max_pos) < abs(self.sentences_max_neg):
                    result = "negative"
                elif abs(self.sentences_max_pos) == abs(self.sentences_max_neg):
                    result = "neutral"
        except:
            print("error ",self.sentences_max_pos, self.sentences_max_neg)
        return result
    def cek_neutral_term(self,terms,i):
        if terms[i-1] in self.neutral_term or terms[i+1] in self.neutral_term: self.score=1 

    def main(self,sentence):
        self.neutral_term = ['jika','kalau']
        sentences = sentence.split('.')
        self.sentences_max_neg = -1
        self.sentences_max_pos = 1
        self.sentences_score = []
        self.sentences_text = []
        for sentence in sentences:
            self.max_neg = -1
            self.max_pos = 1
            self.mean_neg = [1]
            self.mean_pos = [1]
            self.sentence_score=[]
            terms = sentence.split()
            # terms = re.split(r'[\s,.]',sentence)
            terms_length = len(terms)
            self.is_tanya = False
            self.sentence_text = ''
            # print self.max_pos, self.max_neg
            #SEMUA KALIMAT YANG MEMILIKI TANDA SERU MEMILIKI +ve minimal 2
            if self.exclamation_conf and re.search('!',sentence): self.max_pos = 2
            self.prev_score = 0
            self.pre_max_pos = []
            self.pre_max_neg = []
            for i,term in enumerate(terms):
                # repeated_term = ''
                is_extra_char = False
                plural = ''
                self.score = 0
                # if re.search(r'[A-Za-z\-.]+',term):
                # print term
                if re.search(r'([A-Za-z])\1{3,}',term):
                    is_extra_char = True
                    # repeated_term =term
                term = self.remove_extra_repeated_char(term)
                if re.search(r'([A-Za-z]+)\-\1',term):
                    plural = term
                    term = self.plural_to_singular(term)
                #GET SENTI SCORE#
                self.score = self.senti(term)
                # print "senti score",term, self.score

                #NEGATION HANDLER#
                if self.negation_conf and self.score !=0 and i>0:self.cek_negationword(terms[i-1],terms[i-2])
                # print  "negation score",term, self.score

                #BOOSTERWORD HANDLER#
                if self.booster_conf and self.score !=0 and i>0 and i<=(terms_length-1):self.cek_boosterword(terms[i-1])
                if self.booster_conf and self.score !=0 and i>=0 and i<(terms_length-1):self.cek_boosterword(terms[i+1])
                # print  "booster score",term, self.score

                #IDIOM/UNGKAPAN HANDLER#
                if self.ungkapan_conf and i>0 and i<=(terms_length-1):self.cek_ungkapan([terms[i-1],term],[terms[i-2],terms[i-1],term],i)
                # if self.ungkapan_conf and i>=0 and i<(terms_length-1):self.cek_ungkapan([term,terms[i+1]])
                # print  "idiom score",term, self.score

                #CONSECUTIVE SENTIMENT WORD#
                if self.consecutive_conf and i>0 and i<=(terms_length-1) and self.score !=0:self.cek_consecutive_term(terms[i-1])
                # print  "consecutive score",term, self.score

                #+1 SENTI SCORE IF REPEATED CHAR ON POSITIVE/NEGATIVE +2 IF NEUTRAL TERM
                if self.repeated_conf and is_extra_char==True and self.score>0: self.score+=1
                if self.repeated_conf and is_extra_char==True and self.score<0: self.score-=1
                if self.repeated_conf and is_extra_char==True and self.score==0: self.score=2
                # print  "repeat char score", term, self.score
                if self.punctuation_conf and i>=0 and i<(terms_length-1): self.cek_repeated_punctuation(terms[i+1])
                # CEK APAKAH TERDAPAT KATA TANYA
                if self.question_conf and (term in self.tanya or re.search(r'\?',term)):self.is_tanya = True
                # CEK neutral term 
                if self.score!=0 and i>1 and i<(terms_length-2): self.cek_neutral_term(terms,i)
                # if self.score!=0 and i>0 and i<(terms_length-4): self.cek_neutral_term(terms,i)
                if self.emoticon_conf and self.score==0: self.score = self.emosikon(term)

                self.prev_score = self.score
                if self.mean_conf and self.score>0: self.mean_pos.append(self.score)	
                if self.mean_conf and self.score<0: self.mean_neg.append(abs(self.score))
                #GET MAX SCORE +ve/-ve	
                self.max_pos= self.score if self.score > self.max_pos else self.max_pos
                self.max_neg= self.score if self.score < self.max_neg else self.max_neg
                #insert score info current term
                self.pre_max_pos.append(self.max_pos)
                self.pre_max_neg.append(self.max_neg)
                # print self.pre_max_pos, self.pre_max_neg
                if plural !='': term = plural
                self.sentence_text += ' {}'.format(term)
                if self.score != 0:term = "{} [{}]".format(term, self.score)
                self.sentence_score.append(term)

            self.sentences_text.append(self.sentence_text)
            self.sentences_score.append(" ".join(self.sentence_score))
            if self.is_tanya: 
                self.max_neg = -1
            self.sentences_max_pos = self.max_pos if self.max_pos > self.sentences_max_pos else self.sentences_max_pos
            self.sentences_max_neg = self.max_neg if self.max_neg < self.sentences_max_neg else self.sentences_max_neg
            # print self.sentences_max_pos, self.sentences_max_neg
        sentence_result = self.classify()
        # print self.sentences_text
        return {"classified_text":". ".join(self.sentences_score),"tweet_text":". ".join(self.sentences_text),"sentence_score":self.sentences_score,"max_positive":self.sentences_max_pos,"max_negative":self.sentences_max_neg,"kelas":sentence_result}

config = dict()
config["negation"] = True
config["booster"]  = True
config["ungkapan"]  = True
config["consecutive"]  = True
config["repeated"]  = True
config["emoticon"]  = True
config["question"]  = True
config["exclamation"]  = True
config["punctuation"]  = True 
senti = sentistrength(config)

# %% [markdown]
# ## Testing

# %%
print(senti.main("Ini setelah vaksin booster jadi batukkkk.. mana awet sampe skrnggggg yaallah cape:'")['kelas'])
# Out:
# negative

# %% [markdown]
# ## Labelling with Sentistrength

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/tokopedia_sentiment.xlsx')

# %%
df.head()
# Out:
#                                                texts  score    labels
# 0  penanganan komplain barang rusak mengecewakan,...    NaN  negative
# 1                                               good    NaN   neutral
# 2                                       berat appnya    NaN  negative
# 3  Lebih baik ada fitur mengedit alamat pengirima...    NaN  positive
# 4  Pembayaran via VA cuma bisa satu kali. Transak...    NaN  positive

# %%
df = df.drop(['reviewId', 'userName', 'userImage', 'thumbsUpCount', 'at', 'replyContent', 'repliedAt'], axis=1)

# %%
df.rename(columns = {'reviewCreatedVersion':'labels', 'content':'texts'}, inplace = True)

# %%
df.count().texts
# Out:
# 56465

# %%
df = df.astype({"labels": str}, errors='raise')

# %%
for i in range(df.count().texts):
  # if i == 305:
    # continue
  result = senti.main(df.iloc[i]['texts'])['kelas']
  # print(result)
  df.iloc[i, df.columns.get_loc('labels')] = result
  # print(df.iloc[i]['label'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-93d3fce3b8b9> in <module>()
#       2   # if i == 305:
#       3     # continue
# ----> 4   result = senti.main(df.iloc[i]['texts'])['kelas']
#       5   # print(result)
#       6   df.iloc[i, df.columns.get_loc('labels')] = result
#
# <ipython-input-4-101ac972631f> in main(self, sentence)
#     124     def main(self,sentence):
#     125         self.neutral_term = ['jika','kalau']
# --> 126         sentences = sentence.split('.')
#     127         self.sentences_max_neg = -1
#     128         self.sentences_max_pos = 1
#
# AttributeError: 'float' object has no attribute 'split'

# %%
df.head(20)
# Out:
#                                                 texts  score    labels
# 0   penanganan komplain barang rusak mengecewakan,...    NaN  negative
# 1                                                good    NaN   neutral
# 2                                        berat appnya    NaN  negative
# 3   Lebih baik ada fitur mengedit alamat pengirima...    NaN  positive
# 4   Pembayaran via VA cuma bisa satu kali. Transak...    NaN  positive
# 5                                     Semakin bagus..    NaN  positive
# 6   selalu memudahkan pembelian. enaknya nih bisa ...    NaN   neutral
# 7                                                 jos    NaN   neutral
# 8                   Connection problem, please fix it    NaN   neutral
# 9   192 94 ,414茂73171 44u温暖 @ 呃呃实在9峨眉怎么看什么没人狂热，19 ...    NaN   neutral
# 10                                                 ok    NaN   neutral
# 11  Sekarang laggy dari sebelumnya, kenapa sih yan...    NaN   neutral
# 12  transaksi pertama dibatalkan secara sepihak sa...    NaN  negative
# 13  Respon penjual kurang baik, pihak Tokopedia ti...    NaN   neutral
# 14                                   gabisa bayar pbb    NaN   neutral
# 15                             wow mantap gaes tokped    NaN  positive
# 16  performa aplikasi buruk, suka ngelag jika dipa...    NaN  positive
# 17        luarr biasaaaa....makasih tokopedia, SUKAKK    NaN  negative
# 18                                        easy to use    NaN   neutral
# 19  Kasih fitur ganti kurir lah, walau memakai pro...    NaN   neutral

# %%
df.to_excel('tokopedia_sentiment_label.xlsx',index=False)

# %%
df.value_counts("labels")
# Out:
# labels
# nan         207459
# neutral       1633
# positive       726
# negative       386
# dtype: int64

# %% [markdown]
# # Import Data

# %%
#Import Libary
# !pip install Sastrawi
# !pip install swifter
# !pip install emoji
import pandas as pd
import numpy as np
import re
import emoji
import string
import gspread
import seaborn as sns
import matplotlib.pyplot as plt
import swifter
from nltk.tokenize import word_tokenize 
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      |████████████████████████████████| 209 kB 4.3 MB/s
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting swifter
#   Downloading swifter-1.2.0.tar.gz (658 kB)
#      |████████████████████████████████| 658 kB 3.5 MB/s
# Requirement already satisfied: pandas>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (1.3.5)
# Collecting psutil>=5.6.6
#   Downloading psutil-5.9.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (281 kB)
#      |████████████████████████████████| 281 kB 59.2 MB/s
# Requirement already satisfied: dask[dataframe]>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (2.12.0)
# Requirement already satisfied: tqdm>=4.33.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (4.64.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (7.7.1)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from swifter) (1.3.0)
# Requirement already satisfied: parso>0.4.0 in /usr/local/lib/python3.7/dist-packages (from swifter) (0.8.3)
# Requirement already satisfied: bleach>=3.1.1 in /usr/local/lib/python3.7/dist-packages (from swifter) (5.0.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from bleach>=3.1.1->swifter) (1.15.0)
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (1.21.6)
# Collecting partd>=0.3.10
#   Downloading partd-1.2.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: toolz>=0.7.3 in /usr/local/lib/python3.7/dist-packages (from dask[dataframe]>=2.10.0->swifter) (0.11.2)
# Collecting fsspec>=0.6.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 44.4 MB/s
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.5.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (4.10.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (1.1.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.7/dist-packages (from ipywidgets>=7.0.0->swifter) (3.6.1)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.7/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (5.3.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (1.0.18)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (4.4.2)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.8.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (57.4.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->swifter) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Collecting locket
#   Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0->ipywidgets>=7.0.0->swifter) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.7/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.3.1)
# Requirement already satisfied: jupyter-core>=4.4.0 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.11.1)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.4.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.11.3)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.13.3)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.7/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.8.0)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.7/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->swifter) (23.2.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.7/dist-packages (from terminado>=0.8.1->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.0.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (1.5.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.7.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.8.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.7/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.6.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (2.15.3)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.3.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (4.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (21.4.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (5.8.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (0.18.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.7/dist-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.0.0->swifter) (3.8.0)
# Building wheels for collected packages: swifter
#   Building wheel for swifter (setup.py) ... done
#   Created wheel for swifter: filename=swifter-1.2.0-py3-none-any.whl size=14498 sha256=e6c8803764fe0cbb7f3996669e054da61fc7a30f7ff23b9dccffef6aa2d524af
#   Stored in directory: /root/.cache/pip/wheels/b9/c9/ba/10a8fa98de369cd9ed7ff820e6a174cb63a30056b838a0150e
# Successfully built swifter
# Installing collected packages: locket, partd, fsspec, psutil, swifter
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.4.8
#     Uninstalling psutil-5.4.8:
#       Successfully uninstalled psutil-5.4.8
# Successfully installed fsspec-2022.5.0 locket-1.0.0 partd-1.2.0 psutil-5.9.1 swifter-1.2.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting emoji
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#      |████████████████████████████████| 175 kB 4.2 MB/s
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py) ... done
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171046 sha256=dc9188fc793a2ed9d6dd52c1118a1a4dfa2f8a105255c11b0e36a199b5b91bc4
#   Stored in directory: /root/.cache/pip/wheels/8a/4e/b6/57b01db010d17ef6ea9b40300af725ef3e210cb1acfb7ac8b6
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-1.7.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel('/content/drive/MyDrive/Dataset/VaksinasiBoosterDatasetWithLabel.xlsx')
# df = pd.read_excel('/content/dataset.xlsx')

# %%
df.head()
# Out:
#       label                                               text
# 0    netral  hey coba himbau warganya cek seifikat vaksin d...
# 1    netral  mumpung netizen progresif dan berwawasan diban...
# 2  negative  ini setelah vaksin booster jadi batuk mana awe...
# 3  positive  maju loe bible gak takut gw gw dah vaksin booster
# 4  positive          buat sarapan besok sebelum vaksin booster

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   298 non-null    object
#  1   text    298 non-null    object
# dtypes: object(2)
# memory usage: 4.8+ KB

# %% [markdown]
# # Preprocess Data

# %% [markdown]
# ## Drop NaN Column & Drop Duplicate Data

# %%
df.dropna(subset = ["label"], axis=0, inplace=True)

# %%
df = df.drop_duplicates()

# %%
df['label'].value_counts()
# Out:
# negative    187
# positive    157
# neutral     140
# Name: label, dtype: int64

# %%
df['text_real'] = df.text

# %% [markdown]
# ## Remove Link, Hashtag, Mention

# %%
def cleanUpTweet(txt):
    txt = re.sub(r'@[A-Za-z0-9_]+', '', txt) #Remove mentions
    txt = re.sub(r'#[A-Za-z0-9_]+', '', txt) #Remove hashtags
    txt = re.sub(r'RT ', '', txt) #Remove retweets
    txt = re.sub(r'https?:\/\/[A-Za-z0-9\.\/]+', '', txt) #Remove urls
    return txt

# %%
def stripEmoji(txt):
  txt = re.sub(emoji.get_emoji_regexp(), r'', txt)
  return txt

# %%
df['text'] = df['text'].apply(cleanUpTweet)
df['text'] = df['text'].apply(stripEmoji)

# %% [markdown]
# ## Remove HTML Char

# %%
def removeHTMLChar(text):
    text = ' '.join(re.sub("([&][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    return text

# %%
df['text'] = df['text'].apply(removeHTMLChar)

# %% [markdown]
# ## Remove Punctuation

# %%
def remove_punctuation(txt):
  txt = re.sub(r'[^\w\s]', ' ', txt)
  return txt
    # return text.translate(str.maketrans("","",string.punctuation))

# %%
df['text'] = df['text'].apply(remove_punctuation)

# %%
df['text'].iloc[176]
# Out:
# 'Covid     Bikin Vaksin     Vaksin disuntikin     Covid masih ada     Vaksin disuntik lagi     Covid masih ada lagi      booster  disuntikin     Covid udah hampir beres     Muncul Hepatitis  Misterius   Tot ah'

# %%
df.head()
# Out:
#        label                                               text  \
# 1   negative  ini setelah vaksin booster jadi batuk mana awe...
# 2   positive  maju loe bible gak takut gw gw dah vaksin booster
# 4   positive  vaksin booster dulu makannya mas dijamin keman...
# 9   positive  di mainland china kasus covid lagi meledak yg ...
# 10  negative                  abis vaksin booster lemes bgt eww
#
#                                             text_real
# 1   Ini setelah vaksin booster jadi batukkkk.. man...
# 2   RT @rockmansick: MAJU LOE BIBLE GAK TAKUT GW, ...
# 4   @Gondrongsejatix @shitlicious vaksin booster d...
# 9   RT @risyadazhary: Di mainland china kasus covi...
# 10                  abis vaksin booster lemes bgt eww

# %% [markdown]
# ## Remove Whitespace

# %%
def remove_whitespace_LT(text):
    return text.strip()

# %%
def remove_whitespace_multiple(text):
    return re.sub('\s+',' ',text)

# %%
def spell(word):
    if re.search(r'([a-zA-Z])\1{2,}', word):
        rword = re.sub(r'([a-zA-Z])\1{2,}','\\1', word)
        return rword
    else:
        return word

# %%
df['text'] = df['text'].apply(remove_whitespace_LT)
df['text'] = df['text'].apply(remove_whitespace_multiple)
df['text'] = df['text'].apply(spell)

# %% [markdown]
# ## To Lowecase

# %%
df["text"] = df["text"].apply(lambda item: str(item).lower())

# %%
df.to_excel("VaksinasiBoosterDatasetWithLabel.xlsx")

# %%
# Remove Label Netral
df = df[df.label != 'neutral']

# %% [markdown]
# ## Remove Special Character

# %%
def remove_text_special(text):
    # hapus tab, new line, ans back slice
    text = text.replace('\\t'," ").replace('\\n'," ").replace('\\u'," ").replace('\\',"")
    # hapus non ASCII (emot, bahasa china dll)
    text = text.encode('ascii', 'replace').decode('ascii')
    # hapus mention, link, hashtag
    # text = text.replace("rt", "") # revisi
    text = ' '.join(re.sub("([@#&][A-Za-z0-9]+)|(\w+:\/\/\S+)"," ", text).split())
    # remove URL 
    return text.replace("http://", " ").replace("https://", " ")

# %%
df['text'] = df.text.astype('str')                
df['text'] = df['text'].apply(remove_text_special)

# %%
df['text'].iloc[150]
# Out:
# 'efek vaksin booster semalem baru kerasa sekarang mana kerjaan lagi numpuk'

# %% [markdown]
# # Tokenize

# %%
from nltk.tokenize import word_tokenize

# %%
def word_tokenize_wrapper(text):
    return word_tokenize(text)
    
def tokenize(word):
  word = word.split(" ")
  return word

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df['text_tokens'] = df['text'].apply(word_tokenize_wrapper)

# %% [markdown]
# # Count Word

# %%
from collections import defaultdict
word_count = defaultdict(int)
for tokens in df["text_tokens"]:
    for token in tokens:
       word_count[token] += 1

# %%
word_count_df = pd.DataFrame({"key": word_count.keys(), "count": word_count.values()})
word_count_df_sort = word_count_df.sort_values('count', axis=0, ascending=False, inplace=False)
word_count_df_sort.head()
# Out:
#         key  count
# 4    vaksin    600
# 5   booster    513
# 65       yg    106
# 51      dan     99
# 3      udah     79

# %% [markdown]
# # Stopword Removal

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# %%
list_stopwords = stopwords.words('indonesian')
list_stopwords.extend(["yg", "dg", "rt", "dgn", "ny", "d", 'klo', 
                       'kalo', 'amp', 'biar', 'bikin', 'bilang', 
                       'gak', 'ga', 'krn', 'nya', 'nih', 'sih', 
                       'si', 'tau', 'tdk', 'tuh', 'utk', 'ya', 
                       'jd', 'jgn', 'sdh', 'aja', 'n', 't', 
                       'nyg', 'hehe', 'pen', 'u', 'nan', 'loh', 'rt',
                       'yah'])

txt_stopword = pd.read_csv("/content/drive/MyDrive/Dataset/Sentiment Analysis Booster/stopwords.txt", names= ["stopwords"], header = None)
list_stopwords.extend(txt_stopword["stopwords"][0].split(' '))
list_stopwords = set(list_stopwords)
def stopwords_removal(words):
    return [word for word in words if word not in list_stopwords]
df['text_tokens_WSW'] = df['text_tokens'].apply(stopwords_removal)

# %% [markdown]
# # Stemming

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
import swifter

# %%
df_normalized = pd.DataFrame(df['label'])
df_normalized['text'] = df['text']

# %%
normalizad_word = df_normalized

normalizad_word_dict = {}

for index, row in normalizad_word.iterrows():
    if row[0] not in normalizad_word_dict:
        normalizad_word_dict[row[0]] = row[1] 

def normalized_term(document):
    return [normalizad_word_dict[term] if term in normalizad_word_dict else term for term in document]

df['text_normalized'] = df['text_tokens_WSW'].apply(normalized_term)


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}

for document in df['text_normalized']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '
            
print(len(term_dict))
print("------------------------")

for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    print(term,":" ,term_dict[term])
    
print(term_dict)
print("------------------------")


# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]

df['text_tokens_stemmed'] = df['text_normalized'].swifter.apply(get_stemmed_term)
# Out:
# 1900
# ------------------------
# tahan : tahan
# zra : zra
# vaksin : vaksin
# booster : booster
# batuk : batuk
# awet : awet
# sampe : sampe
# skrng : skrng
# yaallah : yaallah
# cape : cape
# maju : maju
# bible : bible
# takut : takut
# sarapan : sarap
# besok : besok
# makannya : makan
# dijamin : jamin
# kemana : mana
# ajah : ajah
# bebas : bebas
# mudah : mudah
# mudahan : mudah
# mudik : mudik
# berangkat : berangkat
# suntik : suntik
# terinfeksi : infeksi
# aktif : aktif
# berfungsi : fungsi
# infeksi : infeksi
# virus : virus
# covid : covid
# 19 : 19
# tunggu : tunggu
# kabar : kabar
# satgas : satgas
# ayo : ayo
# kepentingan : penting
# vaksinmu : vaksin
# melindungimu : lindung
# melindungiku : lindung
# melindungi : lindung
# mari : mari
# ajak : ajak
# jalan2 : jalan2
# pake : pake
# kereta : kereta
# jawa : jawa
# belom : bom
# ibunya : ibu
# disuru : disuru
# mainland : mainland
# china : china
# meledak : ledak
# baiknya : baik
# abis : abis
# lemes : lemes
# eww : eww
# stop : stop
# memperparah : parah
# mutasi : mutasi
# merusak : rusak
# kesehatan : sehat
# efek : efek
# jangka : jangka
# panjangnya : panjang
# menimbulkan : timbul
# penykit : penykit
# menular : tular
# kalah : kalah
# melawan : lawan
# kinn : kinn
# gue : gue
# gebuk : gebuk
# smpe : smpe
# nyakitin : nyakitin
# porsche : porsche
# ditembak : tembak
# udh : udh
# hasil : hasil
# swab : swab
# _ :
# namaku : nama
# mamak : mamak
# kedetek : kedetek
# nunjukin : nunjukin
# sbnrnya : sbnrnya
# bertiga : tiga
# gatau : gatau
# 1 : 1
# 2x : 2x
# pas : pas
# beli : beli
# tiket : tiket
# kosan : kosan
# kerasa : rasa
# canda : canda
# semenjak : semenjak
# ngerasa : ngerasa
# sakit : sakit
# kocak : kocak
# gini : gin
# jancuk : jancuk
# lumayan : lumayan
# beras : beras
# beloman : bom
# disuruh : suruh
# meningitis : meningitis
# japanese : japanese
# encephalitis : encephalitis
# flu : flu
# campak : campak
# rubella : rubella
# etdah : etdah
# jatuh : jatuh
# senin : senin
# libur : libur
# rabu : rabu
# kepala : kepala
# hebat : hebat
# mual : mual
# demam : demam
# kamis : kamis
# meler : meler
# bersin : bersin
# jumat : jumat
# menggigil : gigil
# sabtu : sabtu
# berasa : asa
# bgtt : bgtt
# pegelnya : gel
# pulang : pulang
# badminton : badminton
# tangan : tangan
# kanan : kanan
# ngilu : ngilu
# banget : banget
# siang : siang
# saking : saking
# gegara : gegara
# ngirim : ngirim
# ginian : ginian
# makasih : makasih
# ayu : ayu
# sayangku : sayang
# tuc : tuc
# nonton : nonton
# hrs : hrs
# full : full
# plus : plus
# salah : salah
# antigen : antigen
# bayar : bayar
# 120 : 120
# bath : bath
# gays : gays
# jing : jing
# emg : emg
# syaratnya : syarat
# gila : gila
# skill : skill
# gapake : gapake
# epidemiolog : epidemiolog
# unair : unair
# dukung : dukung
# syarat : syarat
# lebaran : lebaran
# dadakan : dada
# nyuntik : nyuntik
# bokap : bokap
# lol : lol
# bupati : bupati
# husein : husein
# mendorong : dorong
# masyarakat : masyarakat
# divaksin : vaksin
# astra : astra
# tenang : tenang
# temennya : temennya
# zei : zei
# anjeng : anjeng
# gatakut : gatakut
# susah : susah
# info : info
# bekasi : bekas
# huhu : huhu
# telat : telat
# kirain : kirain
# jarak : jarak
# enam : enam
# mrna : mrna
# aware : aware
# milih : milih
# ditolak : tolak
# berkali : kali
# 2 : 2
# moderna : moderna
# dampaknya : dampak
# buset : buset
# 39 : 39
# penerbangan : terbang
# domestik : domestik
# halangan : halang
# sby : sby
# badan : badan
# ngilu2 : ngilu2
# pegel : gel
# kelonggaran : longgar
# pakai : pakai
# surat : surat
# mewajibkan : wajib
# olah : olah
# pemerintah : perintah
# memaksakan : paksa
# pemudik : mudik
# wajib : wajib
# menyelamatkan : selamat
# rakyat : rakyat
# achmad : achmad
# menarik : tarik
# iklannya : iklan
# prokes : prokes
# kombinasi : kombinasi
# pencegahan : cegah
# efikasi : efikasi
# pfizer : pfizer
# 12 : 12
# 7 : 7
# drop : drop
# 0 : 0
# 83 : 83
# johnson : johnson
# dilarang : larang
# az : az
# terduga : duga
# adenovirus : adenovirus
# haram : haram
# kira2 : kira2
# dimksd : dimksd
# ragu : ragu
# aman : aman
# fatwa : fatwa
# halal : halal
# mui : mui
# melengkapi : lengkap
# kuat : kuat
# orang2 : orang2
# ngulang : ngulang
# itb : itb
# kecewa : kecewa
# berat : berat
# habis : habis
# tpi : tpi
# berubah : ubah
# titan : titan
# ness : ness
# happy : happy
# birthday : birthday
# ultahnya : ultahnya
# sm : sm
# kaya : kaya
# ye : ye
# puji : puji
# tuhan : tuhan
# tinggal : tinggal
# nunggu : nunggu
# 3 : 3
# medan : medan
# dh : dh
# masker : masker
# trs : trs
# radang : radang
# tenggorokan : tenggorok
# kemarin : kemarin
# sumpah : sumpah
# semalem : semalem
# sakitnya : sakit
# pagi : pagi
# mereda : reda
# bekas : bekas
# turun : turun
# rggh : rggh
# sembuhnya : sembuh
# asli : asli
# kemaren : kemaren
# niatan : niat
# pengen : ken
# iseng : iseng
# ipad : ipad
# gratis : gratis
# stasiun : stasiun
# gas : gas
# mak : mak
# sinovac : sinovac
# sebenernya : sebenernya
# paham : paham
# 3x : 3x
# ngefek : ngefek
# separah : parah
# pemulihannya : pulih
# cepet : cepet
# minum : minum
# obat : obat
# sehari : hari
# pening : pening
# gara2 : gara2
# pilek : pilek
# glad : glad
# already : already
# fully : fully
# vaccinated : vaccinated
# anjr : anjr
# simulasi : simulasi
# mati : mati
# bneran : bneran
# brp : brp
# dapet : dapet
# suntikan : sunti
# muncul : muncul
# anak2 : anak2
# anti : anti
# misterius2 : misterius2
# isinya : isi
# mmg : mmg
# jeli : jeli
# teliti : teliti
# pintar : pintar
# cuman : cuman
# nggak : nggak
# gajian : gaji
# angka : angka
# warga : warga
# penerima : terima
# bertambah : tambah
# yeah : yeah
# galo : galo
# sertifikat : sertifikat
# pedulilindungi : pedulilindungi
# butuh : butuh
# mood : mood
# solusi : solusi
# akal : akal
# suruh : suruh
# ngeri : ngeri
# panen : panen
# pandemi : pandemi
# penyakit : sakit
# aneh2 : aneh2
# rs : rs
# over : over
# load : load
# kepanikan : panik
# berdoa : doa
# nahkan : nahkan
# gabisa : gabisa
# tidur : tidur
# meriang : meriang
# ketiga : tiga
# klik : klik
# all : all
# brand : brand
# vax : vax
# kelinci : kelinci
# perocbaan : perocbaan
# control : control
# rapidtest : rapidtest
# agswab : agswab
# pcr : pcr
# pemaksaan : paksa
# pengancaman : ancam
# 1000 : 1000
# new : new
# finish : finish
# peti : peti
# dibilang : bilang
# long : long
# komirbit : komirbit
# pejabat : jabat
# bumn : bumn
# berbangga : bangga
# ayok : ayok
# istri : istri
# 6 : 6
# efeknya : efek
# tingkatkan : tingkat
# tercapai : capai
# herd : herd
# imunity : imunity
# amin : amin
# sibuk : sibuk
# pokonyaa : pokonyaa
# make : make
# realised : realised
# keluarga : keluarga
# emang : emang
# bermacam2 : bermacam2
# bingung : bingung
# ngelarang : ngelarang
# gausah : gausah
# untung : untung
# rumah : rumah
# capai : capai
# immunity : immunity
# pantes : pantes
# gampang : gampang
# mleyot : mleyot
# chan : chan
# play : play
# keknya : kek
# ngode : ngode
# dengerin : dengerin
# indo : indo
# sihh : sihh
# sorry : sorry
# gua : gua
# bos : bos
# 5g : 5g
# zombie : zombie
# vaks : vaks
# kanker : kanker
# mycoraditis : mycoraditis
# hepatitis : hepatitis
# stroke : stroke
# impotensi : impotensi
# aq : aq
# ugha : ugha
# dund : dund
# xixixixi : xixixixi
# qm : qm
# umur : umur
# masi : mas
# menyusui : susu
# nyeri : nyeri
# munyak : munyak
# ditempat : tempat
# orangnya : orang
# egois : egois
# kolot : kolot
# kerjanya : kerja
# gada : gada
# bener : bener
# nunggunya : nunggunya
# anjir : anjir
# akun : akun
# gaib : gaib
# kluar : kluar
# cepat : cepat
# mampus : mampus
# universitas : universitas
# indonesia : indonesia
# depok : depok
# berkomorbid : berkomorbid
# sembarang : sembarang
# pribadi : pribadi
# ketahuan : tahu
# autoimunnya : autoimunnya
# sempet : sempet
# lengkap : lengkap
# dosis : dosis
# gapapa : gapapa
# kalem : kalem
# rep : rep
# nyiepin : nyiepin
# berkas : berkas
# drama : drama
# akte : akte
# kelahiran : lahir
# hilang : hilang
# nama : nama
# ortu : ortu
# kk : kk
# bolak : bolak
# capil : capil
# regulasi : regulasi
# mengharuskan : harus
# gaboleh : gaboleh
# batal : batal
# maszeh : maszeh
# kreta : kreta
# allah : allah
# sampingnya : samping
# jarum : jarum
# dimasukin : dimasukin
# malemnya : malemnya
# otw : otw
# subuh : subuh
# 98 : 98
# bln : bln
# mumpung : mumpung
# tolong : tolong
# keperluan : perlu
# live : live
# balbalan : balbalan
# fort : fort
# vastenburg : vastenburg
# adik : adik
# tanggal : tanggal
# 9 : 9
# mei : mei
# capek : capek
# anjing : anjing
# drtd : drtd
# nanya : nanya
# mbak : mbak
# eling : eling
# luwar : luwar
# entuk : entuk
# sungkeman : sungkem
# njero : njero
# isih : isih
# ppkm : ppkm
# level : level
# yen : yen
# yh : yh
# kebanyakan : banyak
# ortunya : ortunya
# dosennya : dosen
# pinter : pinter
# ngelesnya : ngelesnya
# mahasìswaku : mahas swa
# diijinkan : diijinkan
# pdhl : pdhl
# mgkn : mgkn
# males : males
# ngajar : ngajar
# offline : offline
# hihihi : hihihi
# semaran : mar
# solo : solo
# ungaran : ungar
# ngerentek : ngerentek
# adek : adek
# datanya : data
# dinyatakan : nyata
# peduli : peduli
# lindungi : lindung
# sertifikatnya : sertifikat
# dipake : dipake
# ceritanya : cerita
# pesannya : pesan
# ongkir : ongkir
# tetep : tetep
# bahu : bahu
# kiri : kiri
# tertusuknya : tusuk
# ngga : ngga
# mengikuti : ikut
# primer : primer
# nyari : nyari
# puskesmas : puskesmas
# beraya : raya
# pstu : pstu
# tnya : tnya
# kt : kt
# smua : smua
# direct : direct
# terdiam : diam
# member : member
# sbb : sbb
# family : family
# hritu : hritu
# ges : ges
# sinoparm : sinoparm
# bya : bya
# astrazeneca : astrazeneca
# after : after
# gerak : gerak
# dikit : dikit
# sebadan : bad
# kram : kram
# ditensi : tensi
# tch : tch
# lemah : lemah
# kang : kang
# emil : emil
# arus : arus
# barat : barat
# mencapai : capai
# target : target
# landai : landai
# turunkan : turun
# kurve : kurve
# kesakitan : sakit
# ditingkatkan : tingkat
# booth : booth
# dateng : dateng
# kmren : kmren
# badannya : badan
# ampuh : ampuh
# mencegah : cegah
# penularan : tular
# covid19 : covid19
# dbd : dbd
# sembuh : sembuh
# minggu : minggu
# bareng : bareng
# bibi : bibi
# bidan : bidan
# bu : bu
# auto : auto
# ngebatin : ngebatin
# berdar4h : berdar4h
# nembus : nembus
# baju : baju
# lemesin : lemesin
# disuntik : suntik
# hikd : hikd
# ketat : ketat
# strategi : strategi
# cegah : cegah
# keliling : keliling
# buka : buka
# dokternya : dokter
# tebak : tebak
# mermet : mermet
# seutuhnya : utuh
# nga : nga
# akibatnya : akibat
# berlaku : laku
# setau : tau
# cmiiw : cmiiw
# ngobrol : ngobrol
# penumpang : tumpang
# temen : temen
# vitamin : vitamin
# fisik : fisik
# ikhtiar : ikhtiar
# anjuran : anjur
# pusing : pusing
# mikirin : mikirin
# konspirasi : konspirasi
# mintak : mintak
# tlong : tlong
# mengakomodir : mengakomodir
# gotonh : gotonh
# royong : royong
# bisalah : bisa
# pemetintah : tin
# jngnlah : jngnlah
# menyusahkan : susah
# menteri : menteri
# uang : uang
# membeli : beli
# enak2 : enak2
# aturan : atur
# nyeleneh : nyeleneh
# mikir : mikir
# nanggung : nanggung
# pasien : pasien
# mcu : mcu
# haji : haji
# nanya² : nanya
# berceloteh : celoteh
# mengada² : ada
# dokter : dokter
# smp : smp
# dahal : dahal
# anaknya : anak
# bebaskan : bebas
# shay : shay
# engga : engga
# jogging : jogging
# lari : lari
# apapun : apa
# pokoknya : pokok
# sinovak : sinovak
# kebijakan : bijak
# sinopharm : sinopharm
# keuntungan : untung
# nyetadion : nyetadion
# bismillah : bismillah
# iso : iso
# budal : budal
# surabaya : surabaya
# hati2 : hati2
# menyebabkan : sebab
# kemandulan : mandul
# dengar : dengar
# ahli : ahli
# vaksinasi : vaksinasi
# pelengkap : lengkap
# dewasa : dewasa
# 5th : 5th
# bsk : bsk
# cek : cek
# darah : darah
# hahaha : hahaha
# kawan : kawan
# ko : ko
# puasa : puasa
# malem : malem
# boboiboy : boboiboy
# sengaja : sengaja
# bersyukur : syukur
# dapetnya : dapetnya
# cuti : cuti
# besok2 : besok2
# ambil : ambil
# aztrazinidin : aztrazinidin
# panas : panas
# gejala : gejala
# pegal : pegal
# tertandingi : tanding
# bestie : bestie
# bawa2 : bawa2
# bawa : bawa
# mentang2 : mentang2
# basi : basi
# mulu : mulu
# dibawa : bawa
# lupa : lupa
# brother : brother
# koq : koq
# timbul : timbul
# aneh : aneh
# hbs : hbs
# ilang : ilang
# guee : guee
# tengkurep : tengkurep
# pls : pls
# mantap : mantap
# beneran : beneran
# meninggoy : meninggoy
# nangis : nang
# karuan : karuan
# tdi : tdi
# kayaknya : kayak
# semangat : semangat
# nyaranin : nyaranin
# dibela2in : dibela2in
# rajin : rajin
# sha : sha
# jarang : jarang
# es : es
# udara : udara
# dingin : dingin
# makan : makan
# wajar : wajar
# berita : berita
# dok : dok
# dl : dl
# jenis : jenis
# sembarangan : sembarang
# tergantung : gantung
# mu : mu
# semoga : moga
# nemuin : nemuin
# percobaan : coba
# yahmene : yahmene
# mugi2 : mugi2
# rewel : rewel
# awak : awak
# disaat : saat
# staycation : staycation
# jalan : jalan
# meanwhile : meanwhile
# dirumah : rumah
# charge : charge
# energi : energi
# coolyeah : coolyeah
# keja : keja
# mending : mending
# tiba2 : tiba2
# pertandingan : tanding
# pramusim : pramusim
# persija : persija
# dihadiri : hadir
# penonton : tonton
# yekan : yekan
# nanyain : nanyain
# usia : usia
# parno : parno
# misterius : misterius
# virusnya : virus
# beda : beda
# takutt : takutt
# tgl : tgl
# 8 : 8
# sedih : sedih
# perusahaan : usaha
# berpartisipasi : partisipasi
# salahku : salah
# cangkir : cangkir
# kopi : kopi
# gaenak : gaenak
# makanan : makan
# serasa : serasa
# gambar : gambar
# dibawah : bawah
# sedia : sedia
# bpjs : bpjs
# pangku : pangku
# pangkuan : pangku
# sono : sono
# seharian : hari
# ikhlas : ikhlas
# nontoninnha : nontoninnha
# ringkih : ringkih
# gegayaan : gegayaan
# ngebajer : ngebajer
# diperintahkan : perintah
# junjungan : junjung
# paduka : paduka
# mulia : mulia
# jiper : jiper
# disuntikin : disuntikin
# beres : beres
# tot : tot
# ngerasain : ngerasain
# dahlah : dah
# layanan : layan
# terminal : terminal
# tutup : tutup
# tes : tes
# cita : cita
# citanya : cita
# janji : janji
# ketiduran : tidur
# faktanya : fakta
# klaim : klaim
# bukti : bukti
# membenarkan : benar
# aids : aids
# memban : ban
# 1x : 1x
# alasan : alas
# diskriminatif : diskriminatif
# tubuhnya : tubuh
# menerima : terima
# injeksi : injeksi
# kapok : kapok
# mengalami : alami
# kipi : kipi
# sepakbola : sepakbola
# hiburan : hibur
# egaliter : egaliter
# kewajiban : wajib
# tertular : tular
# ktnya : ktnya
# cancer : cancer
# kopit : kopit
# taun : taun
# merencanakan : rencana
# jakarta : jakarta
# merembes : rembes
# cari : cari
# lengan : lengan
# disuntiknya : suntik
# keamanan : aman
# dikasi : kasi
# duit : duit
# njir : njir
# goblok : goblok
# dilaksanakan : laksana
# sehat : sehat
# utamakan : utama
# jaga : jaga
# peps : peps
# memperbolehkan : boleh
# samping : samping
# ngantuk2 : ngantuk2
# ap : ap
# soalny : soalny
# ak : ak
# pelor : pelor
# sakiti : sakit
# tujuan : tuju
# belain : bain
# press : press
# release : release
# big : big
# pharma : pharma
# terkenal : kenal
# shady : shady
# dijadikan : jadi
# dasar : dasar
# dipaksa : paksa
# habiskan : habis
# stok : stok
# kadaluarsa : kadaluarsa
# tanganku : tangan
# perasaan : asa
# sesakit : sakit
# tembakan : tembak
# perlindungan : lindung
# terbaik : baik
# omicron : omicron
# mendapatkann : mendapatkann
# 4 : 4
# penerapan : terap
# kunci : kunci
# terpisahkan : pisah
# potensi : potensi
# kenaikan : naik
# dibarengi : bareng
# disiplin : disiplin
# protokol : protokol
# tott : tott
# deg2am : deg2am
# ajg : ajg
# conspiracy : conspiracy
# event : event
# persebaya : baya
# value : value
# event2 : event2
# peraturan : atur
# habisin : habisin
# ambu : ambu
# pilih : pilih
# kasih : kasih
# peci : peci
# suka : suka
# acara : acara
# mengundang : undang
# turis : turis
# asing : asing
# boosternya : boosternya
# bagus : bagus
# diterapkan : terap
# berburu : buru
# acaranya : acara
# terancam : ancam
# gp : gp
# mandalika : mandalika
# omgg : omgg
# dek : dek
# pacaran : pacar
# wakakaka : wakakaka
# dibotolin : dibotolin
# bwahahahahah : bwahahahahah
# koo : koo
# mundur : mundur
# ud : ud
# silaturahmi : silaturahmi
# perjalanan : jalan
# suasana : suasana
# ramainya : ramai
# rawan : rawan
# anak : anak
# patuh : patuh
# lonjakan : lonjak
# stlh : stlh
# varian : varian
# tertangani : tangan
# moodku : moodku
# jelek : jelek
# marah2 : marah2
# stress : stress
# mal : mal
# genap : genap
# mens : mens
# hari² : hari
# ku : ku
# rame : rame
# travel : travel
# bus : bus
# pke : pke
# tanya2 : tanya2
# fia : fia
# suaminya : suami
# kesulitan : sulit
# akses : akses
# tersedia : sedia
# diakses : akses
# kolektif : kolektif
# perorangan : orang
# persis : persis
# hati : hati
# dapatkan : dapat
# tonton : tonton
# tv : tv
# amankan : aman
# vaksinnya : vaksin
# pns : pns
# karyawan : karyawan
# diganggu : ganggu
# aparat : aparat
# tolak : tolak
# resmi : resmi
# calon : calon
# yak : yak
# nyaman : nyaman
# 80 : 80
# juta : juta
# sepulang : pulang
# anakku : anak
# cewek : cewek
# mslh : mslh
# ursn : ursn
# kampusnya : kampus
# ulu : ulu
# hatinya : hati
# temulawak : temulawak
# lsg : lsg
# tanda2 : tanda2
# berani : berani
# komplit : komplit
# knp : knp
# terpaksa : paksa
# birokrasi : birokrasi
# berusaha : usaha
# posit : posit
# rambut : rambut
# rontok : rontok
# parah : parah
# mendingan : mending
# kyk : kyk
# enggan : enggan
# booste : booste
# ditakutin : ditakutin
# letih : letih
# lesu : lesu
# lhakok : lhakok
# linglung : linglung
# fokus : fokus
# ibukku : ibukku
# unconsciously : unconsciously
# normal : normal
# mirip2 : mirip2
# ngajak : ngajak
# ngeles : ngeles
# hindari : hindar
# bru : bru
# blum : blum
# efekny : efekny
# sebulanan : bulan
# sdangkan : sdangkan
# utbk : utbk
# bntr : bntr
# takutny : takutny
# fit : fit
# acuan : acu
# mjb : mjb
# samsek : samsek
# jeda : jeda
# optional : optional
# dilanjut : lanjut
# tahunan : tahun
# kucingnya : kucing
# jamuran : jamur
# seminggu : minggu
# uda : uda
# cacing : cacing
# maksa : maksa
# dibegoin : dibegoin
# linu : linu
# keluhan : keluh
# nyindir : nyindir
# centrang : centrang
# biru : biru
# 5x : 5x
# menanggapi : tanggap
# postingan : postingan
# 5 : 5
# menunggu : tunggu
# proses : proses
# setuju : tuju
# terombang : terombang
# ambing : ambing
# dipadankan : padan
# kantor : kantor
# menyelenggarakan : selenggara
# fasilitasin : fasilitasin
# dibanding : banding
# masing2 : masing2
# terdekat : dekat
# adiknya : adik
# abangnya : abang
# serang : serang
# teros : ros
# jam : jam
# ringan : ringan
# besoknya : besok
# doang : doang
# pusingnya : pusing
# ganggu : ganggu
# motah : motah
# peserta : serta
# gotong : gotong
# mengaku : aku
# menyesal : sesal
# program : program
# lantaran : lantar
# kerap : kerap
# fasilitas : fasilitas
# diinisiasi : inisiasi
# baca : baca
# bangkit : bangkit
# bawaannya : bawa
# maret : maret
# tmsk : tmsk
# vaksin2 : vaksin2
# lakukan : laku
# membawa : bawa
# kebaikan : baik
# dampak : dampak
# diperbolehkan : boleh
# lintas : lintas
# mengatasi : atas
# penyebaran : sebar
# menakar : takar
# risiko : risiko
# 21 : 21
# 30 : 30
# wib : wib
# membaiknya : baik
# tingginya : tinggi
# capaian : capai
# menciptakan : cipta
# kondusif : kondusif
# kunjungan : kunjung
# wisatawan : wisatawan
# bali : bal
# mancanegara : mancanegara
# berkunjung : kunjung
# meningkat : tingkat
# antri : antri
# anying : anying
# kebal : kebal
# dijatuhin : dijatuhin
# naj : naj
# membantu : bantu
# untungnya : untung
# bertahap : tahap
# deket : deket
# vgr : vgr
# alternatif : alternatif
# heterolog : heterolog
# berbeda : beda
# dikasih : kasih
# 25 : 25
# ml : ml
# dri : dri
# pergi : pergi
# taipei : taipei
# situasinya : situasi
# membaik : baik
# konser : konser
# brapa : brapa
# ratus : ratus
# kesel : kesel
# tkut : tkut
# planing : planing
# curiga : curiga
# berjilid2 : berjilid2
# assembling : assembling
# something : something
# tubuh : tubuh
# ditambah : tambah
# menyempurnakan : sempurna
# sayang : sayang
# pzifer : pzifer
# bacot : bacot
# bahayanya : bahaya
# saraf : saraf
# kejepit : jepit
# ngerti : ngerti
# apa2 : apa2
# karywan : karywan
# toko : toko
# ibuku : ibu
# sino : sino
# leher : leher
# kenpunggung : kenpunggung
# periksa : periksa
# spsaraf : spsaraf
# ditungguin : ditungguin
# chip : chip
# implant : implant
# nanotechno : nanotechno
# biometeic : biometeic
# id : id
# microchip : microchip
# antum : antum
# penyakitan : sakit
# sekarat : sekarat
# beserta : serta
# anada : anada
# rela : rela
# menyerahkan : serah
# dajjal : dajjal
# tunggal : tunggal
# maksudnya : maksud
# siasat : siasat
# pengelabuan : kelabu
# abang : abang
# gamau : gamau
# krna : krna
# wktu : wktu
# terpapar : papar
# bang : bang
# kurun : kurun
# 2021 : 2021
# 2022 : 2022
# prnh : prnh
# awal2 : awal2
# 2020 : 2020
# amit : amit
# smpai : smpai
# perawatan : awat
# murah : murah
# harganya : harga
# nolak : nolak
# media : media
# hrus : hrus
# ngeliatin : ngeliatin
# hnya : hnya
# membesar : besar
# besarkan : besar
# informasi : informasi
# sholat : sholat
# ied : ied
# meluber : luber
# kota : kota
# mall : mall
# penuh : penuh
# pengunjung : unjung
# mestinya : mesti
# status : status
# dicabut : cabut
# waswas : waswas
# lahiran : lahir
# ketemu : ketemu
# aamiin : aamiin
# gunanya : guna
# blok : blok
# hpv : hpv
# diduga : duga
# asap : asap
# api : api
# bermutasi : mutasi
# kejahatan : jahat
# kemanusiaan : manusia
# ingatkan : ingat
# lemhanasan : lemhanasan
# sabar : sabar
# kesabaran : sabar
# stock : stock
# sabarnya : sabar
# jangan2 : jangan2
# semalam : malam
# gatel : gatel
# gatalnya : gatal
# bintik2 : bintik2
# mutualku : mutualku
# relasinya : relasi
# akut : akut
# dunia : dunia
# korban : korban
# mayoritas : mayoritas
# dibwh : dibwh
# 5thn : 5thn
# divaxin : divaxin
# paksa : paksa
# penguasa : kuasa
# mk : mk
# drmn : drmn
# asi : asi
# dobel : dobel
# triple : triple
# lepas : lepas
# aurora : aurora
# buluknya : buluk
# keliatan : liat
# niat : niat
# liburan : libur
# menerapkan : terap
# memutuskan : putus
# lgsg : lgsg
# cabut : cabut
# gigi : gigi
# end : end
# week : week
# nato : nato
# someone : someone
# ecstatic : ecstatic
# pushing : pushing
# her : her
# limit : limit
# edge : edge
# mikrochipnya : mikrochipnya
# meninggal : tinggal
# saiki : saiki
# seneng : neng
# lan : lan
# mangkan : mang
# omongan : omong
# telen : telen
# boarding : boarding
# ketahan : tahan
# grgr : grgr
# february : february
# sertifnya : sertifnya
# gaada : gaada
# gendong : gendong
# brisanol : brisanol
# bangun : bangun
# cha : cha
# dosisnya : dosis
# menyakitkan : sakit
# muslim : muslim
# berbahagia : bahagia
# ribet : ribet
# hidup : hidup
# ribet2 : ribet2
# ketupat : ketupat
# menjaga : jaga
# negara : negara
# beresiko : resiko
# nich : nich
# baku : baku
# hantamnya : hantam
# sok : sok
# keras : keras
# medsos : medsos
# sprt : sprt
# kancut : kancut
# jokowi : jokowi
# tolol : tolol
# melarang : larang
# bpk : bpk
# lue : lue
# bisnis : bisnis
# mendengarkan : dengar
# tante : tante
# bahas : bahas
# wakanda : wakanda
# sikon : sikon
# raya : raya
# diperketat : ketat
# karenan : karenan
# penambahan : tambah
# suspect : suspect
# gelombang : gelombang
# berhasil : hasil
# dilewati : lewat
# lancar : lancar
# persendian : sendi
# delta : delta
# juli : juli
# ikuti : ikut
# 3pekan : 3pekan
# teman2 : teman2
# ngantuk : ngantuk
# keseharianqu : keseharianqu
# jaga2 : jaga2
# kerumunan : kerumun
# berlebih : lebih
# kebantu : bantu
# request : request
# karna : karna
# medis : medis
# cetak : cetak
# kartu : kartu
# bam : bam
# ulang : ulang
# alasannya : alas
# ngomong : ngomong
# sertif : sertif
# kudi : kudi
# siapkan : siap
# lengkapi : lengkap
# horeyy : horeyy
# tumbang : tumbang
# off : off
# panasnya : panas
# kondisi : kondisi
# sapa : sapa
# sembako : sembako
# lemesnya : lemes
# infonya : info
# rada : rada
# kaget : kaget
# pegel2 : pegel2
# nerima : nerima
# blt : blt
# kebucinanku : kebucinanku
# malasku : malas
# orng : orng
# deg : deg
# degan : degan
# laper : laper
# kemarin2 : kemarin2
# sugest : sugest
# nungguin : nungguin
# kyknya : kyknya
# masing² : masing
# dibekas : bekas
# suntikannya : sunti
# temenku : temenku
# izin : izin
# sekian : sekian
# kemalasan : malas
# jogja : jogja
# daftar : daftar
# online : online
# emak : emak
# pemkot : pemkot
# takutnya : takut
# keitung : keitung
# katae : katae
# jompo : jompo
# linu² : linu
# jk : jk
# menuntaskan : tuntas
# 18thn : 18thn
# keatas : atas
# korbankan : korban
# 17 : 17
# notabene : notabene
# maksimal : maksimal
# sesuai : sesuai
# statusnya : status
# 18 : 18
# 18th : 18th
# yrl : yrl
# setang : setang
# semaleman : maleman
# seksrang : seksrang
# mengigil : mengigil
# pala : pala
# pecah : pecah
# melebihi : lebih
# tipis : tipis
# morning : morning
# moots : moots
# prim : prim
# niy : niy
# complete : complete
# cry : cry
# crypas : crypas
# kelas : kelas
# kuota : kuota
# sekolah : sekolah
# merpukana : merpukana
# bentuk : bentuk
# ikhitiar : ikhitiar
# sentra : sentra
# alamin : alamin
# kelenjar : kelenjar
# limpa : limpa
# tulang : tulang
# belikat : belikat
# sisi : sisi
# lokasi : lokasi
# membengkak : bengkak
# ditekan : tekan
# diapa2in : diapa2in
# setelahnya : telah
# bima : bima
# sambut : sambut
# ganjar : ganjar
# jadikan : jadi
# bahagia : bahagia
# gktau : gktau
# airlangga : airlangga
# menghalangi : halang
# kampung : kampung
# halaman : halaman
# dibandingkan : banding
# usap : usap
# pengumuman : umum
# pelonggaran : longgar
# kayanya : kaya
# gabutuh : gabutuh
# ngilangin : ngilangin
# alergi : alergi
# kedinginan : dingin
# kmrn : kmrn
# gkish : gkish
# nyesel : nyesel
# nyebrang : nyebrang
# kapal : kapal
# penduduk : duduk
# mengendalikan : kendali
# minimal : minimal
# jaraknya : jarak
# nalangin : nalangin
# heart : heart
# gencar : gencar
# diadakannya : ada
# alias : alias
# hubungannya : hubung
# cong : cong
# puasanya : puasa
# terbaru : baru
# melampirkan : lampir
# ktp : ktp
# fotokopian : fotokopi
# bolpen : bolpen
# pendaftaran : daftar
# website : website
# kerjaan : kerja
# numpuk : numpuk
# ngapain : ngapain
# daftarin : daftarin
# puskes : puskes
# tips : tips
# berpuasa : puasa
# istirahat : istirahat
# cukupkan : cukup
# kebutuhan : butuh
# cairan : cair
# kegiatan : giat
# sahur : sahur
# kafein : kafein
# manis : manis
# selamat : selamat
# xixi : xixi
# basiannya : basi
# rese : rese
# bing : bing
# patuhi : patuh
# imunitas : imunitas
# biaya : biaya
# test : test
# pesan : pesan
# moral : moral
# duluan : duluan
# barang : barang
# oke : oke
# kelar : kelar
# temen2 : temen2
# boster : boster
# protes : protes
# aparat2 : aparat2
# menghadang : menghadang
# massa : massa
# alat : alat
# hm : hm
# linu2 : linu2
# ngantri : ngantri
# set1 : set1
# mesti : mesti
# ngantor : ngantor
# naek : naek
# ayang : ayang
# pastikan : pasti
# polres : polres
# tasikmalaya : tasikmalaya
# melaksanakan : laksana
# menghadapi : hadap
# persen : persen
# dibooster : dibooster
# apa² : apa
# praktikum : praktikum
# ngambil : ngambil
# awokwpkwok : awokwpkwok
# nekat : nekat
# sekilas : kilas
# membaca : baca
# keriuhan : riuh
# mention : mention
# maaf : maaf
# ditanggapi : tanggap
# optimis : optimis
# depannya : depan
# muter : muter
# jajaran : jajar
# polici : polici
# pemeriksaan : periksa
# dsna : dsna
# persiapan : siap
# diizinin : diizinin
# bukber : bukber
# niatnya : niat
# pindah : pindah
# cafe : cafe
# belok : belok
# efektivitas : efektivitas
# rekomendasinya : rekomendasi
# merk : merk
# kacau : kacau
# bet : bet
# ujan : ujan
# deres : deres
# angin : angin
# banjir : banjir
# nyari2 : nyari2
# muter2 : muter2
# berjam : jam
# motor : motor
# perumahan : rumah
# maksain : maksain
# dikabarin : dikabarin
# daycare : daycare
# bass : bass
# akunya : aku
# foto : foto
# srttifikat : srttifikat
# ngarepin : ngarepin
# nad : nad
# kebayang : bayang
# ngrasain : ngrasain
# saranin : saranin
# 1x24 : 1x24
# 3x24 : 3x24
# buruan : buru
# mjd : mjd
# ngeyel : ngeyel
# kapannya : kapan
# ditusuk : tusuk
# tusuk : tusuk
# ketempatnya : tempat
# nyediain : nyediain
# tuntut : tuntut
# pencabutan : cabut
# pembatasan2 : pembatasan2
# malem2 : malem2
# hmpir : hmpir
# kedatangan : datang
# negeri : negeri
# terkini : kini
# skep : skep
# dinamis : dinamis
# sesuka : suka
# nasib : nasib
# br : br
# sumatera : sumatera
# faskesnya : faskesnya
# dicari : cari
# dimana : mana
# setahu : tahu
# postnya : postnya
# ig : ig
# mastiin : mastiin
# pku : pku
# nutup : nutup
# antriannya : antri
# pagian : pagi
# tmptnya : tmptnya
# gilirannya : gilir
# fasyankes : fasyankes
# pisang : pisang
# biji : biji
# barengan : bareng
# intinya : inti
# banyaknya : banyak
# ngejar : ngejar
# beda2 : beda2
# alhasil : alhasil
# sumeng : sumeng
# effect : effect
# bgitu : bgitu
# ngantukan : ngantukan
# merem : merem
# mimpi : mimpi
# himbauan : himbauan
# kai : kai
# amannya : aman
# penganut : anut
# referensinya : referensi
# drh : drh
# indro : indro
# menganggap : anggap
# tambahan : tambah
# akal2an : akal2an
# oligarki : oligarki
# pondok : pondok
# indah : indah
# menyediakan : sedia
# informasikan : informasi
# sosial : sosial
# terima : terima
# mengherankan : heran
# percaya : percaya
# bawaan : bawa
# tetangga : tetangga
# bbrp : bbrp
# dibilangin : dibilangin
# rentan : rentan
# yeay : yeay
# imunnya : imun
# keamananvaksin : keamananvaksin
# pj : pj
# morton : morton
# impactnya : impactnya
# akibat : akibat
# abal : abal
# taat : taat
# seenggaknya : enggak
# sediikit : sediikit
# tameng : tameng
# copidun : copidun
# finnally : finnally
# undangan : undang
# ngepasin : ngepasin
# senpark : senpark
# alhamdulilah : alhamdulilah
# 10an : 10an
# kondangan : kondangan
# baik2 : baik2
# nyampe : nyampe
# kieu : kieu
# gusti : gusti
# nyuntiknya : nyuntiknya
# semenit : menit
# verifikasi : verifikasi
# lantas : lantas
# trnyata : trnyata
# syekali : syekali
# emak2 : emak2
# toodler : toodler
# usaha : usaha
# prosedur : prosedur
# far : far
# bertahan : tahan
# kakak : kakak
# get : get
# well : well
# soon : soon
# degdegan : degdegan
# asumsi : asumsi
# lebay : lebay
# anget : anget
# prepared : prepared
# its : its
# side : side
# effects : effects
# mualnya : mual
# seserem : rem
# diomongin : diomongin
# gm : gm
# pesen : sen
# halodoc : halodoc
# gercep² : gercep
# antrinya : antri
# 15 : 15
# menitan : menit
# gercep : gercep
# sengal : sengal
# god : god
# sake : sake
# hahah : hahah
# tanteku : tante
# gejalanya : gejala
# pertahanan : tahan
# imun : imun
# jebol : jebol
# nunda2 : nunda2
# bersin2 : bersin2
# sampek : sampek
# berhari : hari
# aman2 : aman2
# mental : mental
# endingnya : endingnya
# snowdrop : snowdrop
# mingguan : minggu
# narasi : narasi
# liar : liar
# mengklaim : klaim
# bertingkah : ting
# layaknya : layak
# beredar : edar
# set : set
# 10 : 10
# td : td
# dahsyat : dahsyat
# efektif : efektif
# pelindung : lindung
# dirasakan : rasa
# buruk : buruk
# larat : larat
# negri : negri
# nun : nun
# disana : sana
# nenggepin : nenggepin
# covidnya : covidnya
# 90 : 90
# laa : laa
# dikita : kita
# opera : opera
# bioskop : bioskop
# baca2 : baca2
# pengalaman : alam
# lawak : lawak
# menikmati : nikmat
# terdengar : dengar
# ceramah : ceramah
# hp : hp
# emosi : emosi
# aplikasi : aplikasi
# tidakpeduli : tidakpeduli
# tidaklindungi : tidaklindungi
# ngaco : ngaco
# spot : spot
# suntiknya : suntik
# adekku : adekku
# denger2 : denger2
# ditunggu : tunggu
# peh : peh
# mengeluh : keluh
# lelah : lelah
# nafsu : nafsu
# jadwal : jadwal
# ibl : ibl
# taunya : tau
# liburnya : libur
# ditumbangkan : tumbang
# 2vaks : 2vaks
# santuy : santuy
# pa : pa
# msuk : msuk
# tida : tida
# today : today
# pegel2nyaa : pegel2nyaa
# mencari : cari
# ngadain : ngadain
# melipir : melipir
# sitik : sitik
# mdh2an : mdh2an
# kenapa2 : kenapa2
# amiin : amiin
# seumur : umur
# antivacc : antivacc
# pokoe : pokoe
# alami : alami
# salahin : salahin
# ignorant : ignorant
# maafkan : maaf
# support : support
# mutual : mutual
# ngangkat : ngangkat
# doain : doain
# cpt : cpt
# smg : smg
# teler : teler
# tambahin : tambahin
# nusuk : nusuk
# harian : hari
# selebihnya : lebih
# suhu : suhu
# dikiitt : dikiitt
# air : air
# putih : putih
# mamaku : mama
# ginjal : ginjal
# krasa : krasa
# hbis : hbis
# bsa : bsa
# tdur : tdur
# enaknya : enak
# smntara : smntara
# paracetamol : paracetamol
# thank : thank
# asking : asking
# about : about
# vaccination : vaccination
# went : went
# im : im
# fine : fine
# stay : stay
# safe : safe
# smuanyaa : smuanyaa
# kejar : kejar
# deadline : deadline
# ttp : ttp
# ngang : ngang
# ngong : ngong
# hobi : hobi
# percepatan : cepat
# pelaksanaan : laksana
# uji : uji
# klinik : klinik
# dsegera : dsegera
# diproduksi : produksi
# damat : damat
# mengakses : akses
# persetujuan : tuju
# eua : eua
# bpom : bpom
# got : got
# zeneca : zeneca
# ke3 : ke3
# anniv : anniv
# uwuww : uwuww
# us : us
# mantapp : mantapp
# bnget : bnget
# pegelpegel : pegelpegel
# hu : hu
# perih : perih
# kebas : kebas
# ngerepotin : ngerepotin
# k24 : k24
# direkomendasikan : rekomendasi
# pola : pola
# kurangi : kurang
# begadang : begadang
# minuman : minum
# olahraga : olahraga
# rutin : rutin
# jujur : jujur
# manfaat : manfaat
# bencik : bencik
# kontra : kontra
# opini : opini
# politik : politik
# anj : anj
# proud : proud
# myself : myself
# {'tahan': 'tahan', 'zra': 'zra', 'vaksin': 'vaksin', 'booster': 'booster', 'batuk': 'batuk', 'awet': 'awet', 'sampe': 'sampe', 'skrng': 'skrng', 'yaallah': 'yaallah', 'cape': 'cape', 'maju': 'maju', 'bible': 'bible', 'takut': 'takut', 'sarapan': 'sarap', 'besok': 'besok', 'makannya': 'makan', 'dijamin': 'jamin', 'kemana': 'mana', 'ajah': 'ajah', 'bebas': 'bebas', 'mudah': 'mudah', 'mudahan': 'mudah', 'mudik': 'mudik', 'berangkat': 'berangkat', 'suntik': 'suntik', 'terinfeksi': 'infeksi', 'aktif': 'aktif', 'berfungsi': 'fungsi', 'infeksi': 'infeksi', 'virus': 'virus', 'covid': 'covid', '19': '19', 'tunggu': 'tunggu', 'kabar': 'kabar', 'satgas': 'satgas', 'ayo': 'ayo', 'kepentingan': 'penting', 'vaksinmu': 'vaksin', 'melindungimu': 'lindung', 'melindungiku': 'lindung', 'melindungi': 'lindung', 'mari': 'mari', 'ajak': 'ajak', 'jalan2': 'jalan2', 'pake': 'pake', 'kereta': 'kereta', 'jawa': 'jawa', 'belom': 'bom', 'ibunya': 'ibu', 'disuru': 'disuru', 'mainland': 'mainland', 'china': 'china', 'meledak': 'ledak', 'baiknya': 'baik', 'abis': 'abis', 'lemes': 'lemes', 'eww': 'eww', 'stop': 'stop', 'memperparah': 'parah', 'mutasi': 'mutasi', 'merusak': 'rusak', 'kesehatan': 'sehat', 'efek': 'efek', 'jangka': 'jangka', 'panjangnya': 'panjang', 'menimbulkan': 'timbul', 'penykit': 'penykit', 'menular': 'tular', 'kalah': 'kalah', 'melawan': 'lawan', 'kinn': 'kinn', 'gue': 'gue', 'gebuk': 'gebuk', 'smpe': 'smpe', 'nyakitin': 'nyakitin', 'porsche': 'porsche', 'ditembak': 'tembak', 'udh': 'udh', 'hasil': 'hasil', 'swab': 'swab', '_': '', 'namaku': 'nama', 'mamak': 'mamak', 'kedetek': 'kedetek', 'nunjukin': 'nunjukin', 'sbnrnya': 'sbnrnya', 'bertiga': 'tiga', 'gatau': 'gatau', '1': '1', '2x': '2x', 'pas': 'pas', 'beli': 'beli', 'tiket': 'tiket', 'kosan': 'kosan', 'kerasa': 'rasa', 'canda': 'canda', 'semenjak': 'semenjak', 'ngerasa': 'ngerasa', 'sakit': 'sakit', 'kocak': 'kocak', 'gini': 'gin', 'jancuk': 'jancuk', 'lumayan': 'lumayan', 'beras': 'beras', 'beloman': 'bom', 'disuruh': 'suruh', 'meningitis': 'meningitis', 'japanese': 'japanese', 'encephalitis': 'encephalitis', 'flu': 'flu', 'campak': 'campak', 'rubella': 'rubella', 'etdah': 'etdah', 'jatuh': 'jatuh', 'senin': 'senin', 'libur': 'libur', 'rabu': 'rabu', 'kepala': 'kepala', 'hebat': 'hebat', 'mual': 'mual', 'demam': 'demam', 'kamis': 'kamis', 'meler': 'meler', 'bersin': 'bersin', 'jumat': 'jumat', 'menggigil': 'gigil', 'sabtu': 'sabtu', 'berasa': 'asa', 'bgtt': 'bgtt', 'pegelnya': 'gel', 'pulang': 'pulang', 'badminton': 'badminton', 'tangan': 'tangan', 'kanan': 'kanan', 'ngilu': 'ngilu', 'banget': 'banget', 'siang': 'siang', 'saking': 'saking', 'gegara': 'gegara', 'ngirim': 'ngirim', 'ginian': 'ginian', 'makasih': 'makasih', 'ayu': 'ayu', 'sayangku': 'sayang', 'tuc': 'tuc', 'nonton': 'nonton', 'hrs': 'hrs', 'full': 'full', 'plus': 'plus', 'salah': 'salah', 'antigen': 'antigen', 'bayar': 'bayar', '120': '120', 'bath': 'bath', 'gays': 'gays', 'jing': 'jing', 'emg': 'emg', 'syaratnya': 'syarat', 'gila': 'gila', 'skill': 'skill', 'gapake': 'gapake', 'epidemiolog': 'epidemiolog', 'unair': 'unair', 'dukung': 'dukung', 'syarat': 'syarat', 'lebaran': 'lebaran', 'dadakan': 'dada', 'nyuntik': 'nyuntik', 'bokap': 'bokap', 'lol': 'lol', 'bupati': 'bupati', 'husein': 'husein', 'mendorong': 'dorong', 'masyarakat': 'masyarakat', 'divaksin': 'vaksin', 'astra': 'astra', 'tenang': 'tenang', 'temennya': 'temennya', 'zei': 'zei', 'anjeng': 'anjeng', 'gatakut': 'gatakut', 'susah': 'susah', 'info': 'info', 'bekasi': 'bekas', 'huhu': 'huhu', 'telat': 'telat', 'kirain': 'kirain', 'jarak': 'jarak', 'enam': 'enam', 'mrna': 'mrna', 'aware': 'aware', 'milih': 'milih', 'ditolak': 'tolak', 'berkali': 'kali', '2': '2', 'moderna': 'moderna', 'dampaknya': 'dampak', 'buset': 'buset', '39': '39', 'penerbangan': 'terbang', 'domestik': 'domestik', 'halangan': 'halang', 'sby': 'sby', 'badan': 'badan', 'ngilu2': 'ngilu2', 'pegel': 'gel', 'kelonggaran': 'longgar', 'pakai': 'pakai', 'surat': 'surat', 'mewajibkan': 'wajib', 'ol ...
# ------------------------
# Pandas Apply:   0%|          | 0/484 [00:00<?, ?it/s]

# %% [markdown]
# # Merge

# %%
def merge_again(text):
    return ' '.join(text)

# %%
df['done_text'] = df['text_tokens_stemmed'].apply(merge_again)

# %%
for i in range(51):
  print(df['done_text'].iloc[i])
# Out:
# tahan zra vaksin booster
# vaksin booster batuk awet sampe skrng yaallah cape
# maju bible takut vaksin booster
# sarap besok vaksin booster
# vaksin booster makan jamin mana ajah bebas
# mudah mudah mudik berangkat mudik suntik vaksin booster infeksi vaksin booster aktif fungsi infeksi virus covid 19 tunggu kabar satgas
# ayo vaksin booster vaksin penting vaksin lindung lindung lindung mari vaksin
# ayo vaksin booster
# ajak jalan2 pake kereta jawa bom vaksin booster ibu disuru booster takut
# mainland china covid ledak booster vaksin baik vaksin
# abis vaksin booster lemes eww
# stop vaksin booster parah mutasi virus rusak sehat efek jangka panjang timbul penykit tular
# kalah lawan vaksin booster
# kinn gue gebuk smpe nyakitin porsche gue takut tembak gue udh vaksin booster
# vaksin booster hasil swab
# nama mamak kedetek vaksin nunjukin sbnrnya tiga udh sampe booster gatau 1 2x vaksin pas beli tiket
# besok udh kosan efek vaksin booster rasa
# ayo vaksin booster
# canda semenjak vaksin booster ngerasa sakit
# efek vaksin booster kocak gin
# vaksin booster
# efek vaksin booster jancuk lumayan beras
# vaksin booster bom suruh vaksin meningitis vaksin japanese encephalitis vaksin flu vaksin campak rubella vaksin etdah
# vaksin booster jatuh sakit covid senin udh libur rabu sakit kepala hebat mual demam kamis sakit kepala mual demam meler bersin jumat mual sakit kepala gigil meler bersin sabtu meler batuk sakit kepala
# asa bgtt gel abis vaksin booster
# pulang badminton tangan kanan ngilu lemes banget siang abis vaksin booster saking lemes sampe
# lemes gegara abis vaksin booster ngirim ginian makasih ayu sayang
# tuc nonton hrs full vaksin plus booster salah antigen bayar 120 bath
# vaksin booster gays
# jing emg syarat vaksin booster gila skill udh gapake
# epidemiolog unair dukung vaksin booster syarat mudik lebaran
# dada vaksin booster nyuntik bokap lol
# bupati husein dorong masyarakat vaksin booster vaksin
# vaksin booster pake astra tenang temennya zei
# maju anjeng gatakut vaksin booster
# yaallah vaksin booster susah info booster bekas huhu
# gin banget efek vaksin booster
# telat vaksin booster kirain jarak vaksin enam
# booster vaksin mrna aware sehat
# milih vaksin tolak kali vaksin 1 2 moderna booster moderna
# vaksin booster dampak rasa buset demam sampe 39 2 vaksin
# terbang domestik 2x vaksin booster
# vaksin 2 vaksin booster
# halang pas sby badan ngilu2 gel asa abis vaksin booster 2x
# longgar pakai surat wajib vaksin booster olah perintah paksa mudik wajib booster vaksin selamat rakyat achmad
# vaksin booster
# ayo vaksin booster
# vaksin booster
# tarik iklan vaksin booster prokes kombinasi cegah covid efikasi pfizer 12 7 drop 0 83 johnson johnson larang az duga adenovirus moderna haram kira2 booster dimksd
# ragu vaksin booster vaksin jamin aman fatwa halal mui prokes mudik
# vaksin booster prokes lengkap prokes mudik

# %% [markdown]
# # Modelling

# %%
# df = df[df['label'] != 'neutral']

# %%
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Setup TFIDF and CountVectorizer

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
tfid = TfidfVectorizer(
    min_df = 3,
    max_df = 0.10,
    ngram_range = (1,2)
)

# %%
count_vect = CountVectorizer(
    min_df = 3,
    max_df = 0.10,
    ngram_range = (1,2)
)

# %%
tfid_result = tfid.fit_transform(df["text"]).toarray() #
tfid_df = pd.DataFrame(tfid_result, columns = tfid.get_feature_names())
tfid_df.columns = ["word_" + str(x) for x in tfid_df.columns]
tfid_df.index = df.index

# %%
cvzr_result = count_vect.fit_transform(df["text"]).toarray() #
cvzr_df = pd.DataFrame(cvzr_result, columns = count_vect.get_feature_names())
cvzr_df.columns = ["word_" + str(x) for x in cvzr_df.columns]
cvzr_df.index = df.index

# %%
cvzr_df.columns
# Out:
# Index(['word_19', 'word_2x', 'word_aamiin', 'word_abis', 'word_abis booster',
#        'word_abis vaksin', 'word_ada efek', 'word_ada vaksin', 'word_adalah',
#        'word_agak',
#        ...
#        'word_yaa', 'word_yah', 'word_yang mau', 'word_yeay', 'word_yg belum',
#        'word_yg bisa', 'word_yg booster', 'word_yg vaksin', 'word_yuk',
#        'word_zombie'],
#       dtype='object', length=521)

# %% [markdown]
# ## Basic Model

# %%
# extract the labels from the train data
y = df.label.values
# use 70% for the training and 30% for the test
x_train, x_test, y_train, y_test = train_test_split(df.text.values, y, #
stratify=y,
random_state=1,
test_size=0.2, shuffle=True)

# %%
# initializing the countvectorizer
vectorizer = CountVectorizer()
# tokenize and make the document into a matrix
document_term_matrix = vectorizer.fit_transform(df['text']) #
# check the result
df_baru = pd.DataFrame(document_term_matrix.toarray(), columns = vectorizer.get_feature_names())

# %%
from sklearn.feature_extraction.text import CountVectorizer
# vectorize tweets for model building
vectorizer = CountVectorizer(binary=True)
# learn a vocabulary dictionary of all tokens in the raw documents
vectorizer.fit(list(x_train) + list(x_test))
# transform documents to document-term matrix
x_train_vec = vectorizer.transform(x_train)
x_test_vec = vectorizer.transform(x_test)

# %%
from sklearn import svm
# classify using support vector classifier
svm = svm.SVC(kernel = 'linear', probability=True)
# fit the SVC model based on the given training data
prob = svm.fit(x_train_vec, y_train).predict_proba(x_test_vec)
# perform classification and prediction on samples in x_test
y_pred_svm = svm.predict(x_test_vec)

# %%
conf_mat = confusion_matrix(y_test, y_pred_svm)
print(conf_mat)
print(classification_report(y_test, y_pred_svm, digits = 4))
# Out:
# [[28 10]
#  [ 8 23]]
#               precision    recall  f1-score   support
#
#     negative     0.7778    0.7368    0.7568        38
#     positive     0.6970    0.7419    0.7188        31
#
#     accuracy                         0.7391        69
#    macro avg     0.7374    0.7394    0.7378        69
# weighted avg     0.7415    0.7391    0.7397        69

# %%
from sklearn.metrics import accuracy_score
print("Accuracy score for SVM is: ", accuracy_score(y_test, y_pred_svm) * 100, '%')
# Out:
# Accuracy score for SVM is:  73.91304347826086 %

# %% [markdown]
# ## Tuning with RBF Kernel

# %%
from sklearn.model_selection import GridSearchCV
 
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']}
 
grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=3)
 
# fitting the model for grid search
grid.fit(x_train_vec, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 2/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 3/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 4/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 5/5] END ........C=0.1, gamma=1, kernel=rbf;, score=0.527 total time=   0.0s
# [CV 1/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 2/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 3/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 4/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 5/5] END ......C=0.1, gamma=0.1, kernel=rbf;, score=0.527 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=0.01, kernel=rbf;, score=0.527 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 2/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 3/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 4/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 5/5] END ....C=0.1, gamma=0.001, kernel=rbf;, score=0.527 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.0001, kernel=rbf;, score=0.527 total time=   0.0s
# [CV 1/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 2/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 3/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 4/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 5/5] END ..........C=1, gamma=1, kernel=rbf;, score=0.527 total time=   0.0s
# [CV 1/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 2/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.727 total time=   0.0s
# [CV 3/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.709 total time=   0.0s
# [CV 4/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.709 total time=   0.0s
# [CV 5/5] END ........C=1, gamma=0.1, kernel=rbf;, score=0.636 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.564 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=0.01, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 2/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 3/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 4/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 5/5] END ......C=1, gamma=0.001, kernel=rbf;, score=0.527 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.0001, kernel=rbf;, score=0.527 total time=   0.0s
# [CV 1/5] END .........C=10, gamma=1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 2/5] END .........C=10, gamma=1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 3/5] END .........C=10, gamma=1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 4/5] END .........C=10, gamma=1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 5/5] END .........C=10, gamma=1, kernel=rbf;, score=0.527 total time=   0.0s
# [CV 1/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.655 total time=   0.0s
# [CV 2/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.764 total time=   0.0s
# [CV 3/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.673 total time=   0.0s
# [CV 4/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.691 total time=   0.0s
# [CV 5/5] END .......C=10, gamma=0.1, kernel=rbf;, score=0.727 total time=   0.0s
# [CV 1/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.782 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.836 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.618 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.782 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=0.01, kernel=rbf;, score=0.673 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.582 total time=   0.0s
# [CV 2/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.655 total time=   0.0s
# [CV 3/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 4/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.600 total time=   0.0s
# [CV 5/5] END .....C=10, gamma=0.001, kernel=rbf;, score=0.564 total time=   0.0s
# [CV 1/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 2/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 3/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 4/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 5/5] END ....C=10, gamma=0.0001, kernel=rbf;, score=0.527 total time=   0.0s
# [CV 1/5] END ........C=100, gamma=1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 2/5] END ........C=100, gamma=1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 3/5] END ........C=100, gamma=1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 4/5] END ........C=100, gamma=1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 5/5] END ........C=100, gamma=1, kernel=rbf;, score=0.527 total time=   0.0s
# [CV 1/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.655 total time=   0.0s
# [CV 2/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.764 total time=   0.0s
# [CV 3/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.673 total time=   0.0s
# [CV 4/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.691 total time=   0.0s
# [CV 5/5] END ......C=100, gamma=0.1, kernel=rbf;, score=0.727 total time=   0.0s
# [CV 1/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.727 total time=   0.0s
# [CV 2/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.782 total time=   0.0s
# [CV 3/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.600 total time=   0.0s
# [CV 4/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.745 total time=   0.0s
# [CV 5/5] END .....C=100, gamma=0.01, kernel=rbf;, score=0.673 total time=   0.0s
# [CV 1/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.782 total time=   0.0s
# [CV 2/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.855 total time=   0.0s
# [CV 3/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.636 total time=   0.0s
# [CV 4/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.782 total time=   0.0s
# [CV 5/5] END ....C=100, gamma=0.001, kernel=rbf;, score=0.673 total time=   0.0s
# [CV 1/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.582 total time=   0.0s
# [CV 2/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.655 total time=   0.0s
# [CV 3/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 4/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.600 total time=   0.0s
# [CV 5/5] END ...C=100, gamma=0.0001, kernel=rbf;, score=0.564 total time=   0.0s
# [CV 1/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 2/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 3/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 4/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.545 total time=   0.0s
# [CV 5/5] END .......C=1000, gamma=1, kernel=rbf;, score=0.527 total time=   0.0s
# [CV 1/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.655 total time=   0.0s
# [CV 2/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.764 total time=   0.0s
# [CV 3/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.673 total time=   0.0s
# [CV 4/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.691 total time=   0.0s
# [CV 5/5] END .....C=1000, gamma=0.1, kernel=rbf;, score=0.727 total time=   0.0s
# [CV 1/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.727 total time=   0.0s
# [CV 2/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.782 total time=   0.0s
# [CV 3/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.600 total time=   0.0s
# [CV 4/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.745 total time=   0.0s
# [CV 5/5] END ....C=1000, gamma=0.01, kernel=rbf;, score=0.673 total time=   0.0s
# [CV 1/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.745 total time=   0.0s
# [CV 2/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.800 total time=   0.0s
# [CV 3/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.600 total time=   0.0s
# [CV 4/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.764 total time=   0.0s
# [CV 5/5] END ...C=1000, gamma=0.001, kernel=rbf;, score=0.655 total time=   0.0s
# [CV 1/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.782 total time=   0.0s
# [CV 2/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.855 total time=   0.0s
# [CV 3/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.636 total time=   0.0s
# [CV 4/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.800 total time=   0.0s
# [CV 5/5] END ..C=1000, gamma=0.0001, kernel=rbf;, score=0.673 total time=   0.0s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              verbose=3)

# %%
# print best parameter after tuning
print(grid.best_params_)
 
# print how our model looks after hyper-parameter tuning
print(grid.best_estimator_)
# Out:
# {'C': 1000, 'gamma': 0.0001, 'kernel': 'rbf'}
# SVC(C=1000, gamma=0.0001)

# %%
grid_predictions = grid.predict(x_test_vec)
 
# print classification report
print(classification_report(y_test, grid_predictions))
print("Accuracy score for SVM is: ", accuracy_score(y_test, grid_predictions) * 100, '%')
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.76      0.76      0.76        38
#     positive       0.71      0.71      0.71        31
#
#     accuracy                           0.74        69
#    macro avg       0.74      0.74      0.74        69
# weighted avg       0.74      0.74      0.74        69
#
# Accuracy score for SVM is:  73.91304347826086 %

# %% [markdown]
# ## Tuning with Linear Kernel

# %%
from sklearn.model_selection import GridSearchCV
 
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['linear']}
 
grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=3)
 
# fitting the model for grid search
grid.fit(x_train_vec, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.764 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.855 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.636 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.818 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=1, kernel=linear;, score=0.691 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.764 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.855 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.636 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.818 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.1, kernel=linear;, score=0.691 total time=   0.0s
# [CV 1/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.764 total time=   0.0s
# [CV 2/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.855 total time=   0.0s
# [CV 3/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.636 total time=   0.0s
# [CV 4/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.818 total time=   0.0s
# [CV 5/5] END ..C=0.1, gamma=0.01, kernel=linear;, score=0.691 total time=   0.0s
# [CV 1/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.764 total time=   0.0s
# [CV 2/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.855 total time=   0.0s
# [CV 3/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.636 total time=   0.0s
# [CV 4/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.818 total time=   0.0s
# [CV 5/5] END .C=0.1, gamma=0.001, kernel=linear;, score=0.691 total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.764 total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.855 total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.636 total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.818 total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.0001, kernel=linear;, score=0.691 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=1, kernel=linear;, score=0.727 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=1, kernel=linear;, score=0.800 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=1, kernel=linear;, score=0.600 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=1, kernel=linear;, score=0.782 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=1, kernel=linear;, score=0.655 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.727 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.800 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.600 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.782 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.1, kernel=linear;, score=0.655 total time=   0.0s
# [CV 1/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.727 total time=   0.0s
# [CV 2/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.800 total time=   0.0s
# [CV 3/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.600 total time=   0.0s
# [CV 4/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.782 total time=   0.0s
# [CV 5/5] END ....C=1, gamma=0.01, kernel=linear;, score=0.655 total time=   0.0s
# [CV 1/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.727 total time=   0.0s
# [CV 2/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.800 total time=   0.0s
# [CV 3/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.600 total time=   0.0s
# [CV 4/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.782 total time=   0.0s
# [CV 5/5] END ...C=1, gamma=0.001, kernel=linear;, score=0.655 total time=   0.0s
# [CV 1/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.727 total time=   0.0s
# [CV 2/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.800 total time=   0.0s
# [CV 3/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.600 total time=   0.0s
# [CV 4/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.782 total time=   0.0s
# [CV 5/5] END ..C=1, gamma=0.0001, kernel=linear;, score=0.655 total time=   0.0s
# [CV 1/5] END ......C=10, gamma=1, kernel=linear;, score=0.727 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=1, kernel=linear;, score=0.800 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=1, kernel=linear;, score=0.600 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=1, kernel=linear;, score=0.782 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=1, kernel=linear;, score=0.655 total time=   0.0s
# [CV 1/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.727 total time=   0.0s
# [CV 2/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.800 total time=   0.0s
# [CV 3/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.600 total time=   0.0s
# [CV 4/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.782 total time=   0.0s
# [CV 5/5] END ....C=10, gamma=0.1, kernel=linear;, score=0.655 total time=   0.0s
# [CV 1/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.727 total time=   0.0s
# [CV 2/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.800 total time=   0.0s
# [CV 3/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.600 total time=   0.0s
# [CV 4/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.782 total time=   0.0s
# [CV 5/5] END ...C=10, gamma=0.01, kernel=linear;, score=0.655 total time=   0.0s
# [CV 1/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.727 total time=   0.0s
# [CV 2/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.800 total time=   0.0s
# [CV 3/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.600 total time=   0.0s
# [CV 4/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.782 total time=   0.0s
# [CV 5/5] END ..C=10, gamma=0.001, kernel=linear;, score=0.655 total time=   0.0s
# [CV 1/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.727 total time=   0.0s
# [CV 2/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.800 total time=   0.0s
# [CV 3/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.600 total time=   0.0s
# [CV 4/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.782 total time=   0.0s
# [CV 5/5] END .C=10, gamma=0.0001, kernel=linear;, score=0.655 total time=   0.0s
# [CV 1/5] END .....C=100, gamma=1, kernel=linear;, score=0.727 total time=   0.0s
# [CV 2/5] END .....C=100, gamma=1, kernel=linear;, score=0.800 total time=   0.0s
# [CV 3/5] END .....C=100, gamma=1, kernel=linear;, score=0.600 total time=   0.0s
# [CV 4/5] END .....C=100, gamma=1, kernel=linear;, score=0.782 total time=   0.0s
# [CV 5/5] END .....C=100, gamma=1, kernel=linear;, score=0.655 total time=   0.0s
# [CV 1/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.727 total time=   0.0s
# [CV 2/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.800 total time=   0.0s
# [CV 3/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.600 total time=   0.0s
# [CV 4/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.782 total time=   0.0s
# [CV 5/5] END ...C=100, gamma=0.1, kernel=linear;, score=0.655 total time=   0.0s
# [CV 1/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.727 total time=   0.0s
# [CV 2/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.800 total time=   0.0s
# [CV 3/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.600 total time=   0.0s
# [CV 4/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.782 total time=   0.0s
# [CV 5/5] END ..C=100, gamma=0.01, kernel=linear;, score=0.655 total time=   0.0s
# [CV 1/5] END .C=100, gamma=0.001, kernel=linear;, score=0.727 total time=   0.0s
# [CV 2/5] END .C=100, gamma=0.001, kernel=linear;, score=0.800 total time=   0.0s
# [CV 3/5] END .C=100, gamma=0.001, kernel=linear;, score=0.600 total time=   0.0s
# [CV 4/5] END .C=100, gamma=0.001, kernel=linear;, score=0.782 total time=   0.0s
# [CV 5/5] END .C=100, gamma=0.001, kernel=linear;, score=0.655 total time=   0.0s
# [CV 1/5] END C=100, gamma=0.0001, kernel=linear;, score=0.727 total time=   0.0s
# [CV 2/5] END C=100, gamma=0.0001, kernel=linear;, score=0.800 total time=   0.0s
# [CV 3/5] END C=100, gamma=0.0001, kernel=linear;, score=0.600 total time=   0.0s
# [CV 4/5] END C=100, gamma=0.0001, kernel=linear;, score=0.782 total time=   0.0s
# [CV 5/5] END C=100, gamma=0.0001, kernel=linear;, score=0.655 total time=   0.0s
# [CV 1/5] END ....C=1000, gamma=1, kernel=linear;, score=0.727 total time=   0.0s
# [CV 2/5] END ....C=1000, gamma=1, kernel=linear;, score=0.800 total time=   0.0s
# [CV 3/5] END ....C=1000, gamma=1, kernel=linear;, score=0.600 total time=   0.0s
# [CV 4/5] END ....C=1000, gamma=1, kernel=linear;, score=0.782 total time=   0.0s
# [CV 5/5] END ....C=1000, gamma=1, kernel=linear;, score=0.655 total time=   0.0s
# [CV 1/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.727 total time=   0.0s
# [CV 2/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.800 total time=   0.0s
# [CV 3/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.600 total time=   0.0s
# [CV 4/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.782 total time=   0.0s
# [CV 5/5] END ..C=1000, gamma=0.1, kernel=linear;, score=0.655 total time=   0.0s
# [CV 1/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.727 total time=   0.0s
# [CV 2/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.800 total time=   0.0s
# [CV 3/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.600 total time=   0.0s
# [CV 4/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.782 total time=   0.0s
# [CV 5/5] END .C=1000, gamma=0.01, kernel=linear;, score=0.655 total time=   0.0s
# [CV 1/5] END C=1000, gamma=0.001, kernel=linear;, score=0.727 total time=   0.0s
# [CV 2/5] END C=1000, gamma=0.001, kernel=linear;, score=0.800 total time=   0.0s
# [CV 3/5] END C=1000, gamma=0.001, kernel=linear;, score=0.600 total time=   0.0s
# [CV 4/5] END C=1000, gamma=0.001, kernel=linear;, score=0.782 total time=   0.0s
# [CV 5/5] END C=1000, gamma=0.001, kernel=linear;, score=0.655 total time=   0.0s
# [CV 1/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.727 total time=   0.0s
# [CV 2/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.800 total time=   0.0s
# [CV 3/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.600 total time=   0.0s
# [CV 4/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.782 total time=   0.0s
# [CV 5/5] END C=1000, gamma=0.0001, kernel=linear;, score=0.655 total time=   0.0s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['linear']},
#              verbose=3)

# %%
print(grid.best_params_)
print(grid.best_estimator_)
# Out:
# {'C': 0.1, 'gamma': 1, 'kernel': 'linear'}
# SVC(C=0.1, gamma=1, kernel='linear')

# %%
grid_predictions = grid.predict(x_test_vec)

print(classification_report(y_test, grid_predictions))
print("Accuracy score for SVM is: ", accuracy_score(y_test, grid_predictions) * 100, '%')
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.74      0.82      0.78        38
#     positive       0.74      0.65      0.69        31
#
#     accuracy                           0.74        69
#    macro avg       0.74      0.73      0.73        69
# weighted avg       0.74      0.74      0.74        69
#
# Accuracy score for SVM is:  73.91304347826086 %

# %% [markdown]
# ## Tuning with Polynomial Kernel

# %%
from sklearn.model_selection import GridSearchCV
 
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['poly']}
 
grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=3)
 
# fitting the model for grid search
grid.fit(x_train_vec, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.618 total time=   0.0s
# [CV 2/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.764 total time=   0.0s
# [CV 3/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.618 total time=   0.0s
# [CV 4/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.745 total time=   0.0s
# [CV 5/5] END .......C=0.1, gamma=1, kernel=poly;, score=0.636 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.564 total time=   0.0s
# [CV 2/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.564 total time=   0.0s
# [CV 3/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.545 total time=   0.0s
# [CV 4/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.545 total time=   0.0s
# [CV 5/5] END .....C=0.1, gamma=0.1, kernel=poly;, score=0.527 total time=   0.0s
# [CV 1/5] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.545 total time=   0.0s
# [CV 2/5] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.545 total time=   0.0s
# [CV 3/5] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.545 total time=   0.0s
# [CV 4/5] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.545 total time=   0.0s
# [CV 5/5] END ....C=0.1, gamma=0.01, kernel=poly;, score=0.527 total time=   0.0s
# [CV 1/5] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 2/5] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 3/5] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 4/5] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 5/5] END ...C=0.1, gamma=0.001, kernel=poly;, score=0.527 total time=   0.0s
# [CV 1/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 2/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 3/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 4/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 5/5] END ..C=0.1, gamma=0.0001, kernel=poly;, score=0.527 total time=   0.0s
# [CV 1/5] END .........C=1, gamma=1, kernel=poly;, score=0.618 total time=   0.0s
# [CV 2/5] END .........C=1, gamma=1, kernel=poly;, score=0.764 total time=   0.0s
# [CV 3/5] END .........C=1, gamma=1, kernel=poly;, score=0.618 total time=   0.0s
# [CV 4/5] END .........C=1, gamma=1, kernel=poly;, score=0.745 total time=   0.0s
# [CV 5/5] END .........C=1, gamma=1, kernel=poly;, score=0.636 total time=   0.0s
# [CV 1/5] END .......C=1, gamma=0.1, kernel=poly;, score=0.655 total time=   0.0s
# [CV 2/5] END .......C=1, gamma=0.1, kernel=poly;, score=0.818 total time=   0.0s
# [CV 3/5] END .......C=1, gamma=0.1, kernel=poly;, score=0.673 total time=   0.0s
# [CV 4/5] END .......C=1, gamma=0.1, kernel=poly;, score=0.764 total time=   0.0s
# [CV 5/5] END .......C=1, gamma=0.1, kernel=poly;, score=0.582 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=0.01, kernel=poly;, score=0.545 total time=   0.0s
# [CV 2/5] END ......C=1, gamma=0.01, kernel=poly;, score=0.545 total time=   0.0s
# [CV 3/5] END ......C=1, gamma=0.01, kernel=poly;, score=0.545 total time=   0.0s
# [CV 4/5] END ......C=1, gamma=0.01, kernel=poly;, score=0.545 total time=   0.0s
# [CV 5/5] END ......C=1, gamma=0.01, kernel=poly;, score=0.527 total time=   0.0s
# [CV 1/5] END .....C=1, gamma=0.001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 2/5] END .....C=1, gamma=0.001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 3/5] END .....C=1, gamma=0.001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 4/5] END .....C=1, gamma=0.001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 5/5] END .....C=1, gamma=0.001, kernel=poly;, score=0.527 total time=   0.0s
# [CV 1/5] END ....C=1, gamma=0.0001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 2/5] END ....C=1, gamma=0.0001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 3/5] END ....C=1, gamma=0.0001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 4/5] END ....C=1, gamma=0.0001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 5/5] END ....C=1, gamma=0.0001, kernel=poly;, score=0.527 total time=   0.0s
# [CV 1/5] END ........C=10, gamma=1, kernel=poly;, score=0.618 total time=   0.0s
# [CV 2/5] END ........C=10, gamma=1, kernel=poly;, score=0.764 total time=   0.0s
# [CV 3/5] END ........C=10, gamma=1, kernel=poly;, score=0.618 total time=   0.0s
# [CV 4/5] END ........C=10, gamma=1, kernel=poly;, score=0.745 total time=   0.0s
# [CV 5/5] END ........C=10, gamma=1, kernel=poly;, score=0.636 total time=   0.0s
# [CV 1/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.600 total time=   0.0s
# [CV 2/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.800 total time=   0.0s
# [CV 3/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.600 total time=   0.0s
# [CV 4/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.727 total time=   0.0s
# [CV 5/5] END ......C=10, gamma=0.1, kernel=poly;, score=0.636 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=0.01, kernel=poly;, score=0.545 total time=   0.0s
# [CV 2/5] END .....C=10, gamma=0.01, kernel=poly;, score=0.545 total time=   0.0s
# [CV 3/5] END .....C=10, gamma=0.01, kernel=poly;, score=0.545 total time=   0.0s
# [CV 4/5] END .....C=10, gamma=0.01, kernel=poly;, score=0.545 total time=   0.0s
# [CV 5/5] END .....C=10, gamma=0.01, kernel=poly;, score=0.527 total time=   0.0s
# [CV 1/5] END ....C=10, gamma=0.001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 2/5] END ....C=10, gamma=0.001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 3/5] END ....C=10, gamma=0.001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 4/5] END ....C=10, gamma=0.001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 5/5] END ....C=10, gamma=0.001, kernel=poly;, score=0.527 total time=   0.0s
# [CV 1/5] END ...C=10, gamma=0.0001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 2/5] END ...C=10, gamma=0.0001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 3/5] END ...C=10, gamma=0.0001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 4/5] END ...C=10, gamma=0.0001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 5/5] END ...C=10, gamma=0.0001, kernel=poly;, score=0.527 total time=   0.0s
# [CV 1/5] END .......C=100, gamma=1, kernel=poly;, score=0.618 total time=   0.0s
# [CV 2/5] END .......C=100, gamma=1, kernel=poly;, score=0.764 total time=   0.0s
# [CV 3/5] END .......C=100, gamma=1, kernel=poly;, score=0.618 total time=   0.0s
# [CV 4/5] END .......C=100, gamma=1, kernel=poly;, score=0.745 total time=   0.0s
# [CV 5/5] END .......C=100, gamma=1, kernel=poly;, score=0.636 total time=   0.0s
# [CV 1/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.618 total time=   0.0s
# [CV 2/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.764 total time=   0.0s
# [CV 3/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.618 total time=   0.0s
# [CV 4/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.745 total time=   0.0s
# [CV 5/5] END .....C=100, gamma=0.1, kernel=poly;, score=0.636 total time=   0.0s
# [CV 1/5] END ....C=100, gamma=0.01, kernel=poly;, score=0.564 total time=   0.0s
# [CV 2/5] END ....C=100, gamma=0.01, kernel=poly;, score=0.564 total time=   0.0s
# [CV 3/5] END ....C=100, gamma=0.01, kernel=poly;, score=0.545 total time=   0.0s
# [CV 4/5] END ....C=100, gamma=0.01, kernel=poly;, score=0.545 total time=   0.0s
# [CV 5/5] END ....C=100, gamma=0.01, kernel=poly;, score=0.527 total time=   0.0s
# [CV 1/5] END ...C=100, gamma=0.001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 2/5] END ...C=100, gamma=0.001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 3/5] END ...C=100, gamma=0.001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 4/5] END ...C=100, gamma=0.001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 5/5] END ...C=100, gamma=0.001, kernel=poly;, score=0.527 total time=   0.0s
# [CV 1/5] END ..C=100, gamma=0.0001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 2/5] END ..C=100, gamma=0.0001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 3/5] END ..C=100, gamma=0.0001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 4/5] END ..C=100, gamma=0.0001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 5/5] END ..C=100, gamma=0.0001, kernel=poly;, score=0.527 total time=   0.0s
# [CV 1/5] END ......C=1000, gamma=1, kernel=poly;, score=0.618 total time=   0.0s
# [CV 2/5] END ......C=1000, gamma=1, kernel=poly;, score=0.764 total time=   0.0s
# [CV 3/5] END ......C=1000, gamma=1, kernel=poly;, score=0.618 total time=   0.0s
# [CV 4/5] END ......C=1000, gamma=1, kernel=poly;, score=0.745 total time=   0.0s
# [CV 5/5] END ......C=1000, gamma=1, kernel=poly;, score=0.636 total time=   0.0s
# [CV 1/5] END ....C=1000, gamma=0.1, kernel=poly;, score=0.618 total time=   0.0s
# [CV 2/5] END ....C=1000, gamma=0.1, kernel=poly;, score=0.764 total time=   0.0s
# [CV 3/5] END ....C=1000, gamma=0.1, kernel=poly;, score=0.618 total time=   0.0s
# [CV 4/5] END ....C=1000, gamma=0.1, kernel=poly;, score=0.745 total time=   0.0s
# [CV 5/5] END ....C=1000, gamma=0.1, kernel=poly;, score=0.636 total time=   0.0s
# [CV 1/5] END ...C=1000, gamma=0.01, kernel=poly;, score=0.655 total time=   0.0s
# [CV 2/5] END ...C=1000, gamma=0.01, kernel=poly;, score=0.818 total time=   0.0s
# [CV 3/5] END ...C=1000, gamma=0.01, kernel=poly;, score=0.673 total time=   0.0s
# [CV 4/5] END ...C=1000, gamma=0.01, kernel=poly;, score=0.764 total time=   0.0s
# [CV 5/5] END ...C=1000, gamma=0.01, kernel=poly;, score=0.582 total time=   0.0s
# [CV 1/5] END ..C=1000, gamma=0.001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 2/5] END ..C=1000, gamma=0.001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 3/5] END ..C=1000, gamma=0.001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 4/5] END ..C=1000, gamma=0.001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 5/5] END ..C=1000, gamma=0.001, kernel=poly;, score=0.527 total time=   0.0s
# [CV 1/5] END .C=1000, gamma=0.0001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 2/5] END .C=1000, gamma=0.0001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 3/5] END .C=1000, gamma=0.0001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 4/5] END .C=1000, gamma=0.0001, kernel=poly;, score=0.545 total time=   0.0s
# [CV 5/5] END .C=1000, gamma=0.0001, kernel=poly;, score=0.527 total time=   0.0s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['poly']},
#              verbose=3)

# %%
print(grid.best_params_)
print(grid.best_estimator_)
# Out:
# {'C': 1, 'gamma': 0.1, 'kernel': 'poly'}
# SVC(C=1, gamma=0.1, kernel='poly')

# %%
grid_predictions = grid.predict(x_test_vec)

print(classification_report(y_test, grid_predictions))
print("Accuracy score for SVM is: ", accuracy_score(y_test, grid_predictions) * 100, '%')
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.69      0.82      0.75        38
#     positive       0.71      0.55      0.62        31
#
#     accuracy                           0.70        69
#    macro avg       0.70      0.68      0.68        69
# weighted avg       0.70      0.70      0.69        69
#
# Accuracy score for SVM is:  69.56521739130434 %

# %% [markdown]
# ## Tuning with Sigmoid Kernel

# %%
from sklearn.model_selection import GridSearchCV
 
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['sigmoid']}
 
grid = GridSearchCV(SVC(), param_grid, refit=True, verbose=3)
 
# fitting the model for grid search
grid.fit(x_train_vec, y_train)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ....C=0.1, gamma=1, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 2/5] END ....C=0.1, gamma=1, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 3/5] END ....C=0.1, gamma=1, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 4/5] END ....C=0.1, gamma=1, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 5/5] END ....C=0.1, gamma=1, kernel=sigmoid;, score=0.527 total time=   0.0s
# [CV 1/5] END ..C=0.1, gamma=0.1, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 2/5] END ..C=0.1, gamma=0.1, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 3/5] END ..C=0.1, gamma=0.1, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 4/5] END ..C=0.1, gamma=0.1, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 5/5] END ..C=0.1, gamma=0.1, kernel=sigmoid;, score=0.527 total time=   0.0s
# [CV 1/5] END .C=0.1, gamma=0.01, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 2/5] END .C=0.1, gamma=0.01, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 3/5] END .C=0.1, gamma=0.01, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 4/5] END .C=0.1, gamma=0.01, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 5/5] END .C=0.1, gamma=0.01, kernel=sigmoid;, score=0.527 total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.001, kernel=sigmoid;, score=0.527 total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.0001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.0001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.0001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.0001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.0001, kernel=sigmoid;, score=0.527 total time=   0.0s
# [CV 1/5] END ......C=1, gamma=1, kernel=sigmoid;, score=0.582 total time=   0.0s
# [CV 2/5] END ......C=1, gamma=1, kernel=sigmoid;, score=0.564 total time=   0.0s
# [CV 3/5] END ......C=1, gamma=1, kernel=sigmoid;, score=0.527 total time=   0.0s
# [CV 4/5] END ......C=1, gamma=1, kernel=sigmoid;, score=0.564 total time=   0.0s
# [CV 5/5] END ......C=1, gamma=1, kernel=sigmoid;, score=0.491 total time=   0.0s
# [CV 1/5] END ....C=1, gamma=0.1, kernel=sigmoid;, score=0.745 total time=   0.0s
# [CV 2/5] END ....C=1, gamma=0.1, kernel=sigmoid;, score=0.800 total time=   0.0s
# [CV 3/5] END ....C=1, gamma=0.1, kernel=sigmoid;, score=0.655 total time=   0.0s
# [CV 4/5] END ....C=1, gamma=0.1, kernel=sigmoid;, score=0.782 total time=   0.0s
# [CV 5/5] END ....C=1, gamma=0.1, kernel=sigmoid;, score=0.618 total time=   0.0s
# [CV 1/5] END ...C=1, gamma=0.01, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 2/5] END ...C=1, gamma=0.01, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 3/5] END ...C=1, gamma=0.01, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 4/5] END ...C=1, gamma=0.01, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 5/5] END ...C=1, gamma=0.01, kernel=sigmoid;, score=0.527 total time=   0.0s
# [CV 1/5] END ..C=1, gamma=0.001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 2/5] END ..C=1, gamma=0.001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 3/5] END ..C=1, gamma=0.001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 4/5] END ..C=1, gamma=0.001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 5/5] END ..C=1, gamma=0.001, kernel=sigmoid;, score=0.527 total time=   0.0s
# [CV 1/5] END .C=1, gamma=0.0001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 2/5] END .C=1, gamma=0.0001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 3/5] END .C=1, gamma=0.0001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 4/5] END .C=1, gamma=0.0001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 5/5] END .C=1, gamma=0.0001, kernel=sigmoid;, score=0.527 total time=   0.0s
# [CV 1/5] END .....C=10, gamma=1, kernel=sigmoid;, score=0.636 total time=   0.0s
# [CV 2/5] END .....C=10, gamma=1, kernel=sigmoid;, score=0.600 total time=   0.0s
# [CV 3/5] END .....C=10, gamma=1, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 4/5] END .....C=10, gamma=1, kernel=sigmoid;, score=0.600 total time=   0.0s
# [CV 5/5] END .....C=10, gamma=1, kernel=sigmoid;, score=0.400 total time=   0.0s
# [CV 1/5] END ...C=10, gamma=0.1, kernel=sigmoid;, score=0.691 total time=   0.0s
# [CV 2/5] END ...C=10, gamma=0.1, kernel=sigmoid;, score=0.800 total time=   0.0s
# [CV 3/5] END ...C=10, gamma=0.1, kernel=sigmoid;, score=0.727 total time=   0.0s
# [CV 4/5] END ...C=10, gamma=0.1, kernel=sigmoid;, score=0.691 total time=   0.0s
# [CV 5/5] END ...C=10, gamma=0.1, kernel=sigmoid;, score=0.673 total time=   0.0s
# [CV 1/5] END ..C=10, gamma=0.01, kernel=sigmoid;, score=0.764 total time=   0.0s
# [CV 2/5] END ..C=10, gamma=0.01, kernel=sigmoid;, score=0.836 total time=   0.0s
# [CV 3/5] END ..C=10, gamma=0.01, kernel=sigmoid;, score=0.636 total time=   0.0s
# [CV 4/5] END ..C=10, gamma=0.01, kernel=sigmoid;, score=0.818 total time=   0.0s
# [CV 5/5] END ..C=10, gamma=0.01, kernel=sigmoid;, score=0.691 total time=   0.0s
# [CV 1/5] END .C=10, gamma=0.001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 2/5] END .C=10, gamma=0.001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 3/5] END .C=10, gamma=0.001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 4/5] END .C=10, gamma=0.001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 5/5] END .C=10, gamma=0.001, kernel=sigmoid;, score=0.527 total time=   0.0s
# [CV 1/5] END C=10, gamma=0.0001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 2/5] END C=10, gamma=0.0001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 3/5] END C=10, gamma=0.0001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 4/5] END C=10, gamma=0.0001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 5/5] END C=10, gamma=0.0001, kernel=sigmoid;, score=0.527 total time=   0.0s
# [CV 1/5] END ....C=100, gamma=1, kernel=sigmoid;, score=0.582 total time=   0.0s
# [CV 2/5] END ....C=100, gamma=1, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 3/5] END ....C=100, gamma=1, kernel=sigmoid;, score=0.600 total time=   0.0s
# [CV 4/5] END ....C=100, gamma=1, kernel=sigmoid;, score=0.618 total time=   0.0s
# [CV 5/5] END ....C=100, gamma=1, kernel=sigmoid;, score=0.418 total time=   0.0s
# [CV 1/5] END ..C=100, gamma=0.1, kernel=sigmoid;, score=0.655 total time=   0.0s
# [CV 2/5] END ..C=100, gamma=0.1, kernel=sigmoid;, score=0.727 total time=   0.0s
# [CV 3/5] END ..C=100, gamma=0.1, kernel=sigmoid;, score=0.691 total time=   0.0s
# [CV 4/5] END ..C=100, gamma=0.1, kernel=sigmoid;, score=0.673 total time=   0.0s
# [CV 5/5] END ..C=100, gamma=0.1, kernel=sigmoid;, score=0.655 total time=   0.0s
# [CV 1/5] END .C=100, gamma=0.01, kernel=sigmoid;, score=0.727 total time=   0.0s
# [CV 2/5] END .C=100, gamma=0.01, kernel=sigmoid;, score=0.800 total time=   0.0s
# [CV 3/5] END .C=100, gamma=0.01, kernel=sigmoid;, score=0.618 total time=   0.0s
# [CV 4/5] END .C=100, gamma=0.01, kernel=sigmoid;, score=0.782 total time=   0.0s
# [CV 5/5] END .C=100, gamma=0.01, kernel=sigmoid;, score=0.655 total time=   0.0s
# [CV 1/5] END C=100, gamma=0.001, kernel=sigmoid;, score=0.764 total time=   0.0s
# [CV 2/5] END C=100, gamma=0.001, kernel=sigmoid;, score=0.855 total time=   0.0s
# [CV 3/5] END C=100, gamma=0.001, kernel=sigmoid;, score=0.636 total time=   0.0s
# [CV 4/5] END C=100, gamma=0.001, kernel=sigmoid;, score=0.818 total time=   0.0s
# [CV 5/5] END C=100, gamma=0.001, kernel=sigmoid;, score=0.691 total time=   0.0s
# [CV 1/5] END C=100, gamma=0.0001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 2/5] END C=100, gamma=0.0001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 3/5] END C=100, gamma=0.0001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 4/5] END C=100, gamma=0.0001, kernel=sigmoid;, score=0.545 total time=   0.0s
# [CV 5/5] END C=100, gamma=0.0001, kernel=sigmoid;, score=0.527 total time=   0.0s
# [CV 1/5] END ...C=1000, gamma=1, kernel=sigmoid;, score=0.636 total time=   0.0s
# [CV 2/5] END ...C=1000, gamma=1, kernel=sigmoid;, score=0.582 total time=   0.0s
# [CV 3/5] END ...C=1000, gamma=1, kernel=sigmoid;, score=0.600 total time=   0.0s
# [CV 4/5] END ...C=1000, gamma=1, kernel=sigmoid;, score=0.582 total time=   0.0s
# [CV 5/5] END ...C=1000, gamma=1, kernel=sigmoid;, score=0.418 total time=   0.0s
# [CV 1/5] END .C=1000, gamma=0.1, kernel=sigmoid;, score=0.655 total time=   0.0s
# [CV 2/5] END .C=1000, gamma=0.1, kernel=sigmoid;, score=0.727 total time=   0.0s
# [CV 3/5] END .C=1000, gamma=0.1, kernel=sigmoid;, score=0.764 total time=   0.0s
# [CV 4/5] END .C=1000, gamma=0.1, kernel=sigmoid;, score=0.673 total time=   0.0s
# [CV 5/5] END .C=1000, gamma=0.1, kernel=sigmoid;, score=0.655 total time=   0.0s
# [CV 1/5] END C=1000, gamma=0.01, kernel=sigmoid;, score=0.727 total time=   0.0s
# [CV 2/5] END C=1000, gamma=0.01, kernel=sigmoid;, score=0.800 total time=   0.0s
# [CV 3/5] END C=1000, gamma=0.01, kernel=sigmoid;, score=0.618 total time=   0.0s
# [CV 4/5] END C=1000, gamma=0.01, kernel=sigmoid;, score=0.782 total time=   0.0s
# [CV 5/5] END C=1000, gamma=0.01, kernel=sigmoid;, score=0.655 total time=   0.0s
# [CV 1/5] END C=1000, gamma=0.001, kernel=sigmoid;, score=0.727 total time=   0.0s
# [CV 2/5] END C=1000, gamma=0.001, kernel=sigmoid;, score=0.800 total time=   0.0s
# [CV 3/5] END C=1000, gamma=0.001, kernel=sigmoid;, score=0.600 total time=   0.0s
# [CV 4/5] END C=1000, gamma=0.001, kernel=sigmoid;, score=0.782 total time=   0.0s
# [CV 5/5] END C=1000, gamma=0.001, kernel=sigmoid;, score=0.655 total time=   0.0s
# [CV 1/5] END C=1000, gamma=0.0001, kernel=sigmoid;, score=0.764 total time=   0.0s
# [CV 2/5] END C=1000, gamma=0.0001, kernel=sigmoid;, score=0.855 total time=   0.0s
# [CV 3/5] END C=1000, gamma=0.0001, kernel=sigmoid;, score=0.636 total time=   0.0s
# [CV 4/5] END C=1000, gamma=0.0001, kernel=sigmoid;, score=0.818 total time=   0.0s
# [CV 5/5] END C=1000, gamma=0.0001, kernel=sigmoid;, score=0.691 total time=   0.0s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['sigmoid']},
#              verbose=3)

# %%
print(grid.best_params_)
print(grid.best_estimator_)
# Out:
# {'C': 100, 'gamma': 0.001, 'kernel': 'sigmoid'}
# SVC(C=100, gamma=0.001, kernel='sigmoid')

# %%
grid_predictions = grid.predict(x_test_vec)

print(classification_report(y_test, grid_predictions))
print("Accuracy score for SVM is: ", accuracy_score(y_test, grid_predictions) * 100, '%')
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.74      0.82      0.78        38
#     positive       0.74      0.65      0.69        31
#
#     accuracy                           0.74        69
#    macro avg       0.74      0.73      0.73        69
# weighted avg       0.74      0.74      0.74        69
#
# Accuracy score for SVM is:  73.91304347826086 %

# %% [markdown]
# ## Compare with Different Tuning Model

# %%
kernels = ['Polynomial', 'RBF', 'Sigmoid','Linear']#A function which returns the corresponding SVC model
def getClassifier(ktype):
    if ktype == 0:
        # Polynomial kernal
        return SVC(kernel='poly', degree=8, gamma="auto")
    elif ktype == 1:
        # Radial Basis Function kernal
        return SVC(kernel='rbf', gamma="auto")
    elif ktype == 2:
        # Sigmoid kernal
        return SVC(kernel='sigmoid', gamma="auto")
    elif ktype == 3:
        # Linear kernal
        return SVC(kernel='linear', gamma="auto")

# %%
for i in range(4):
    svclassifier = getClassifier(i) 
    svclassifier.fit(x_train_vec, y_train)
    y_pred = svclassifier.predict(x_test_vec)
    print("Evaluation:", kernels[i], "kernel")
    print(classification_report(y_test,y_pred))
# Out:
# Evaluation: Polynomial kernel
#               precision    recall  f1-score   support
#
#     negative       0.55      1.00      0.71        38
#     positive       0.00      0.00      0.00        31
#
#     accuracy                           0.55        69
#    macro avg       0.28      0.50      0.36        69
# weighted avg       0.30      0.55      0.39        69
#
# Evaluation: RBF kernel
#               precision    recall  f1-score   support
#
#     negative       0.55      1.00      0.71        38
#     positive       0.00      0.00      0.00        31
#
#     accuracy                           0.55        69
#    macro avg       0.28      0.50      0.36        69
# weighted avg       0.30      0.55      0.39        69
#
# Evaluation: Sigmoid kernel
#               precision    recall  f1-score   support
#
#     negative       0.55      1.00      0.71        38
#     positive       0.00      0.00      0.00        31
#
#     accuracy                           0.55        69
#    macro avg       0.28      0.50      0.36        69
# weighted avg       0.30      0.55      0.39        69
#
# Evaluation: Linear kernel
#               precision    recall  f1-score   support
#
#     negative       0.78      0.74      0.76        38
#     positive       0.70      0.74      0.72        31
#
#     accuracy                           0.74        69
#    macro avg       0.74      0.74      0.74        69
# weighted avg       0.74      0.74      0.74        69
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'C': [0.1, 1, 10, 100], 
    'gamma': [1, 0.1, 0.01, 0.001],
    'kernel': ['rbf', 'poly', 'sigmoid']
}

# %%
grid = GridSearchCV(SVC(),param_grid,refit=True,verbose=2)
grid.fit(x_train_vec, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=0.1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, gamma=1, kernel=poly; total time=   0.0s
# [CV] END ........................C=0.1, gamma=1, kernel=poly; total time=   0.0s
# [CV] END ........................C=0.1, gamma=1, kernel=poly; total time=   0.0s
# [CV] END ........................C=0.1, gamma=1, kernel=poly; total time=   0.0s
# [CV] END ........................C=0.1, gamma=1, kernel=poly; total time=   0.0s
# [CV] END .....................C=0.1, gamma=1, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=0.1, gamma=1, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=0.1, gamma=1, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=0.1, gamma=1, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=0.1, gamma=1, kernel=sigmoid; total time=   0.0s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=0.1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END ...................C=0.1, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=0.1, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=0.1, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=0.1, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=0.1, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=0.1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.01, kernel=poly; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.01, kernel=poly; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.01, kernel=poly; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.01, kernel=poly; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.01, kernel=poly; total time=   0.0s
# [CV] END ..................C=0.1, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END ..................C=0.1, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END ..................C=0.1, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END ..................C=0.1, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END ..................C=0.1, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=0.1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ....................C=0.1, gamma=0.001, kernel=poly; total time=   0.0s
# [CV] END ....................C=0.1, gamma=0.001, kernel=poly; total time=   0.0s
# [CV] END ....................C=0.1, gamma=0.001, kernel=poly; total time=   0.0s
# [CV] END ....................C=0.1, gamma=0.001, kernel=poly; total time=   0.0s
# [CV] END ....................C=0.1, gamma=0.001, kernel=poly; total time=   0.0s
# [CV] END .................C=0.1, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV] END .................C=0.1, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV] END .................C=0.1, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV] END .................C=0.1, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV] END .................C=0.1, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ...........................C=1, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=1, gamma=1, kernel=poly; total time=   0.0s
# [CV] END ..........................C=1, gamma=1, kernel=poly; total time=   0.0s
# [CV] END ..........................C=1, gamma=1, kernel=poly; total time=   0.0s
# [CV] END ..........................C=1, gamma=1, kernel=poly; total time=   0.0s
# [CV] END ..........................C=1, gamma=1, kernel=poly; total time=   0.0s
# [CV] END .......................C=1, gamma=1, kernel=sigmoid; total time=   0.0s
# [CV] END .......................C=1, gamma=1, kernel=sigmoid; total time=   0.0s
# [CV] END .......................C=1, gamma=1, kernel=sigmoid; total time=   0.0s
# [CV] END .......................C=1, gamma=1, kernel=sigmoid; total time=   0.0s
# [CV] END .......................C=1, gamma=1, kernel=sigmoid; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=1, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END ........................C=1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END ........................C=1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END ........................C=1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END ........................C=1, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END .....................C=1, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=1, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=1, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=1, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=1, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ........................C=1, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.01, kernel=poly; total time=   0.0s
# [CV] END .......................C=1, gamma=0.01, kernel=poly; total time=   0.0s
# [CV] END .......................C=1, gamma=0.01, kernel=poly; total time=   0.0s
# [CV] END .......................C=1, gamma=0.01, kernel=poly; total time=   0.0s
# [CV] END .......................C=1, gamma=0.01, kernel=poly; total time=   0.0s
# [CV] END ....................C=1, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=1, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=1, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=1, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=1, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ......................C=1, gamma=0.001, kernel=poly; total time=   0.0s
# [CV] END ......................C=1, gamma=0.001, kernel=poly; total time=   0.0s
# [CV] END ......................C=1, gamma=0.001, kernel=poly; total time=   0.0s
# [CV] END ......................C=1, gamma=0.001, kernel=poly; total time=   0.0s
# [CV] END ......................C=1, gamma=0.001, kernel=poly; total time=   0.0s
# [CV] END ...................C=1, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ..........................C=10, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=10, gamma=1, kernel=poly; total time=   0.0s
# [CV] END .........................C=10, gamma=1, kernel=poly; total time=   0.0s
# [CV] END .........................C=10, gamma=1, kernel=poly; total time=   0.0s
# [CV] END .........................C=10, gamma=1, kernel=poly; total time=   0.0s
# [CV] END .........................C=10, gamma=1, kernel=poly; total time=   0.0s
# [CV] END ......................C=10, gamma=1, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=10, gamma=1, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=10, gamma=1, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=10, gamma=1, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=10, gamma=1, kernel=sigmoid; total time=   0.0s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=10, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=10, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END .......................C=10, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END .......................C=10, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END .......................C=10, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END .......................C=10, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END ....................C=10, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=10, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=10, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=10, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=10, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .......................C=10, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=10, gamma=0.01, kernel=poly; total time=   0.0s
# [CV] END ......................C=10, gamma=0.01, kernel=poly; total time=   0.0s
# [CV] END ......................C=10, gamma=0.01, kernel=poly; total time=   0.0s
# [CV] END ......................C=10, gamma=0.01, kernel=poly; total time=   0.0s
# [CV] END ......................C=10, gamma=0.01, kernel=poly; total time=   0.0s
# [CV] END ...................C=10, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=10, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=10, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=10, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=10, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=10, gamma=0.001, kernel=poly; total time=   0.0s
# [CV] END .....................C=10, gamma=0.001, kernel=poly; total time=   0.0s
# [CV] END .....................C=10, gamma=0.001, kernel=poly; total time=   0.0s
# [CV] END .....................C=10, gamma=0.001, kernel=poly; total time=   0.0s
# [CV] END .....................C=10, gamma=0.001, kernel=poly; total time=   0.0s
# [CV] END ..................C=10, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV] END ..................C=10, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV] END ..................C=10, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV] END ..................C=10, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV] END ..................C=10, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END .........................C=100, gamma=1, kernel=rbf; total time=   0.0s
# [CV] END ........................C=100, gamma=1, kernel=poly; total time=   0.0s
# [CV] END ........................C=100, gamma=1, kernel=poly; total time=   0.0s
# [CV] END ........................C=100, gamma=1, kernel=poly; total time=   0.0s
# [CV] END ........................C=100, gamma=1, kernel=poly; total time=   0.0s
# [CV] END ........................C=100, gamma=1, kernel=poly; total time=   0.0s
# [CV] END .....................C=100, gamma=1, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=100, gamma=1, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=100, gamma=1, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=100, gamma=1, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=100, gamma=1, kernel=sigmoid; total time=   0.0s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END .......................C=100, gamma=0.1, kernel=rbf; total time=   0.0s
# [CV] END ......................C=100, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END ......................C=100, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END ......................C=100, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END ......................C=100, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END ......................C=100, gamma=0.1, kernel=poly; total time=   0.0s
# [CV] END ...................C=100, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=100, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=100, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=100, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=100, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END ......................C=100, gamma=0.01, kernel=rbf; total time=   0.0s
# [CV] END .....................C=100, gamma=0.01, kernel=poly; total time=   0.0s
# [CV] END .....................C=100, gamma=0.01, kernel=poly; total time=   0.0s
# [CV] END .....................C=100, gamma=0.01, kernel=poly; total time=   0.0s
# [CV] END .....................C=100, gamma=0.01, kernel=poly; total time=   0.0s
# [CV] END .....................C=100, gamma=0.01, kernel=poly; total time=   0.0s
# [CV] END ..................C=100, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END ..................C=100, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END ..................C=100, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END ..................C=100, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END ..................C=100, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   0.0s
# [CV] END ....................C=100, gamma=0.001, kernel=poly; total time=   0.0s
# [CV] END ....................C=100, gamma=0.001, kernel=poly; total time=   0.0s
# [CV] END ....................C=100, gamma=0.001, kernel=poly; total time=   0.0s
# [CV] END ....................C=100, gamma=0.001, kernel=poly; total time=   0.0s
# [CV] END ....................C=100, gamma=0.001, kernel=poly; total time=   0.0s
# [CV] END .................C=100, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV] END .................C=100, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV] END .................C=100, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV] END .................C=100, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV] END .................C=100, gamma=0.001, kernel=sigmoid; total time=   0.0s
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001],
#                          'kernel': ['rbf', 'poly', 'sigmoid']},
#              verbose=2)

# %%
print(grid.best_params_)
print(grid.best_estimator_)
# Out:
# {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
# SVC(C=10, gamma=0.01)

# %%
grid_predictions = grid.predict(x_test_vec)

print(confusion_matrix(y_test, grid_predictions))
print(classification_report(y_test, grid_predictions))
# Out:
# [[30 11  8]
#  [ 6 22  9]
#  [12  8 21]]
#               precision    recall  f1-score   support
#
#     negative       0.62      0.61      0.62        49
#      neutral       0.54      0.59      0.56        37
#     positive       0.55      0.51      0.53        41
#
#     accuracy                           0.57       127
#    macro avg       0.57      0.57      0.57       127
# weighted avg       0.58      0.57      0.57       127

# %%
from sklearn.metrics import accuracy_score
print("Accuracy score for SVM is: ", accuracy_score(y_test, y_pred_svm) * 100, '%')
# Out:
# Accuracy score for SVM is:  55.90551181102362 %
